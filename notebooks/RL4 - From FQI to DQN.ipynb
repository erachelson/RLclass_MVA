# %% [markdown]
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" align="left" src="https://i.creativecommons.org/l/by-nc-sa/4.0/80x15.png" /></a>&nbsp;| [Emmanuel Rachelson](https://personnel.isae-supaero.fr/emmanuel-rachelson?lang=en) | <a href="https://erachelson.github.io/RLclass_MVA/">https://erachelson.github.io/RLclass_MVA/</a>

# %% [markdown]
# <div style="font-size:22pt; line-height:25pt; font-weight:bold; text-align:center;">Chapter 4: From fitted Q-iteration to deep Q-networks</div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Learning outcomes**
# By the end of this chapter, you should be able to:
# - hello world
#
# Additionally, after doing the homework, you should be able to:
# - hello world
# </div>

# %% [markdown]
# # Environments

# %% [markdown]
# In this chapter, we depart from toy problems and dive into larger scale ones, with the intention to build approximate value iteration algorithms that scale to challenging environments.
#
# - cart-pole
# - swing-up
# - acrobot or lunar lander or bipedal walker (actions discretized)
# - pong

# %% [markdown]
# ## Cart-pole
#
# Full description on the [gymnasium website](https://gymnasium.farama.org/environments/classic_control/cart_pole/).
#
# > A pole is attached by an un-actuated joint to a cart, which moves along a frictionless track. The pendulum is placed upright on the cart and the goal is to balance the pole by applying forces in the left and right direction on the cart.

# %%
import gymnasium as gym
import matplotlib.pyplot as plt
cartpole = gym.make('CartPole-v1', render_mode="rgb_array")
print("Observation space:", cartpole.observation_space)
print("Action space:", cartpole.action_space)
s,_ = cartpole.reset()
print("Starting state:", s)
plt.imshow(cartpole.render());

# %%
import gymnasium as gym
cartpole = gym.make('CartPole-v1', render_mode="human")
s,_ = cartpole.reset()
for t in range(200):
    s2,r,d,trunc,_ = cartpole.step(cartpole.action_space.sample())
    cartpole.render()
    if d:
        break

# %%
cartpole.close()

# %% [markdown]
# ## Acrobot
#
# Full description on the [gymnasium website](https://gymnasium.farama.org/environments/classic_control/acrobot/).
#
# > The system consists of two links connected linearly to form a chain, with one end of the chain fixed. The joint between the two links is actuated. The goal is to apply torques on the actuated joint to swing the free end of the linear chain above a given height while starting from the initial state of hanging downwards.

# %%
import gymnasium as gym
import matplotlib.pyplot as plt
acrobot = gym.make('Acrobot-v1', render_mode="rgb_array")
print("Observation space:", acrobot.observation_space)
print("Action space:", acrobot.action_space)
s,_ = acrobot.reset()
print("Starting state:", s)
plt.imshow(acrobot.render());

# %%
import gymnasium as gym
acrobot = gym.make('Acrobot-v1', render_mode="human")
s,_ = acrobot.reset()
for t in range(200):
    s2,r,d,trunc,_ = acrobot.step(acrobot.action_space.sample())
    acrobot.render()
    if d:
        break

# %%
acrobot.close()

# %% [markdown]
# # Fitted Q-iteration

# %% [markdown]
# ## Reminder: AVI as a series of risk minimization problems
#
# <div class="alert alert-success">
#
# **Approximate value iteration as a sequence of risk minimization problems**
# $$\pi_n \in \mathcal{G} Q_n,$$
# $$L_n(\theta) = \frac{1}{2} \mathbb{E}_{(s,a) \sim \rho}\left[ \left( Q(s,a;\theta) - G^{\pi_n}_1(s,a,Q_n) \right)^2 \right],$$
# $$\theta_{n+1} \in \arg\min_{\theta} L_n(\theta),$$
# $$Q_{n+1}(s,a) = Q(s,a;\theta_{n+1}).$$
# </div>
#
# With
# $$\pi \in \mathcal{G} Q, \Leftrightarrow \pi(s) \in \arg\max_{\pi \in \Delta_A} \mathbb{E}_{a\sim\pi} \left[Q(s,a)\right]$$
#
# And
# $$G^\pi_1(s,a,Q) = R_0 + \gamma Q(S_1, A_1) \quad \Bigg| \quad \begin{array}{l}S_0 = s, A_0=a\\ A_1 \sim \pi(S_1),\\ S_{1}\sim p(\cdot|S_0,A_0),\\ R_0 = r(S_0,A_0,S_{1}).\end{array}$$

# %% [markdown]
# In the previous chapter, we saw that the exact, tabular representation of $Q$ was actually a linear model. In turn, this opened the possibility to use stochastic approximation to solve the $\min_\theta L_n(\theta)$ problem, leading to Q-learning and SARSA.
#
# Such representations do not scale to large state spaces, and we know we should turn to function approximation sooner or later.
# Given iid samples $(s,a,r,s')$, solving $\min_\theta L_n(\theta)$ translates to a supervised learning problem whose inputs $x$ are $x=(s,a)$ pairs, and outputs $y$ are $y=r+\gamma \mathbb{E}_{a'\sim \pi_n(s')} Q_n(s',a')$.
#
# While, in the previous chapter, stochastic approximation enabled learning $\min_\theta L_n(\theta)$ with on-the-fly acquired samples (provided the function approximator was differentiable), it seems reasonable to enable storage of samples, leading to a training set of iid samples $\{(s,a,r,s')\}$ which we called an *experience replay memory* or *replay buffer*: with this, the regression problem now has a function representation space and a training set of input-output pairs $\{(x,y)\}$.
#
# The supervised learning literature provides us with a span of efficient methods to solve such a regression problem.
# Random forests is a reasonably all-purpose method, with great properties in many cases: let's build a sample-based AVI method using random forests.
#
# In general, the use of supervised learning regressors as approximators of the sequence of AVI's Q-functions is called **fitted Q-iteration (FQI)**.

# %% [markdown]
# ## A random forest based FQI algorithm.

# %% [markdown]
# One often considers that the two historical papers implementing FQI algorithms are the ones describing **[Tree-Based Batch Mode Reinforcement Learning](https://www.jmlr.org/papers/volume6/ernst05a/ernst05a.pdf)** (Ernst et al., 2005) and **[Neural Fitted Q Iteration](https://link.springer.com/chapter/10.1007/11564096_32)** (Riedmiller, 2005). Of course they were not the only ones but they are often quoted as milestones in RL history.
#
# We are going to implement an algorithm which is very close to that presented in the Tree-Based Batch Mode Reinforcement Learning paper. The main difference is that the authors employed a variant of random forests called extra trees. Scikit-learn provides an implementation of both random forests and extra trees, feel free to swap one for the other in what follows.
#
# The first step to perform FQI is to collect and store a dataset of samples.
# <div class="alert alert-warning">
#
# **Exercise:**
# Collect $10^4$ samples using a uniformly random policy and store them.
# </div>

# %%
import numpy as np
from tqdm import tqdm

def collect_samples(env, horizon, disable_tqdm=False, print_done_states=False):
    s, _ = env.reset()
    #dataset = []
    S = []
    A = []
    R = []
    S2 = []
    D = []
    for _ in tqdm(range(horizon), disable=disable_tqdm):
        a = env.action_space.sample()
        s2, r, done, trunc, _ = env.step(a)
        #dataset.append((s,a,r,s2,done,trunc))
        S.append(s)
        A.append(a)
        R.append(r)
        S2.append(s2)
        D.append(done)
        if done or trunc:
            s, _ = env.reset()
            if done and print_done_states:
                print("done!")
        else:
            s = s2
    S = np.array(S)
    A = np.array(A).reshape((-1,1))
    R = np.array(R)
    S2= np.array(S2)
    D = np.array(D)
    return S, A, R, S2, D

# %%
import gymnasium as gym
cartpole = gym.make('CartPole-v1', render_mode="rgb_array")
S,A,R,S2,D = collect_samples(cartpole, int(1e4))
print("nb of collected samples:", S.shape[0])
for i in range(3):
    print("sample", i, "\n  state:", S[i], "\n  action:", A[i], "\n  reward:", R[i], "\n  next state:", S2[i], "\n terminal?", D[i])

# %% [markdown]
# Now let's consider $Q_0$ is the constant zero function and train a random forest to learn $Q_1$.
#
# <div class="alert alert-warning">
#
# **Exercise:**
# Construct the training set to learn $Q_1$, then train it.
# </div>

# %%
from sklearn.ensemble import RandomForestRegressor
import numpy as np

SA = np.append(S,A,axis=1)
value = R.copy()

Q1 = RandomForestRegressor()
Q1.fit(SA,value);

# %%
# compute MSE
print("training MSE:", np.mean((value-Q1.predict(SA))**2))

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Restart from scratch and write the loop that builds the sequence of AVI Q-functions. Store all successive Q-functions.
# </div>

# %%
# %load solutions/rf_fqi.py
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from tqdm import tqdm

def rf_fqi(S, A, R, S2, D, iterations, nb_actions, gamma, disable_tqdm=False):
    nb_samples = S.shape[0]
    Qfunctions = []
    SA = np.append(S,A,axis=1)
    for iter in tqdm(range(iterations), disable=disable_tqdm):
        if iter==0:
            value=R.copy()
        else:
            Q2 = np.zeros((nb_samples,nb_actions))
            for a2 in range(nb_actions):
                A2 = a2*np.ones((S.shape[0],1))
                S2A2 = np.append(S2,A2,axis=1)
                Q2[:,a2] = Qfunctions[-1].predict(S2A2)
            max_Q2 = np.max(Q2,axis=1)
            value = R + gamma*(1-D)*max_Q2
        Q = RandomForestRegressor()
        Q.fit(SA,value)
        Qfunctions.append(Q)
    return Qfunctions

# %%
gamma = .9
nb_iter = 10
nb_actions = cartpole.action_space.n
Qfunctions = rf_fqi(S, A, R, S2, D, nb_iter, nb_actions, gamma)

# %%
import matplotlib.pyplot as plt

# Value of an initial state across iterations
s0,_ = cartpole.reset()
Vs0 = np.zeros(nb_iter)
for i in range(nb_iter):
    Qs0a = []
    for a in range(cartpole.action_space.n):
        s0a = np.append(s0,a).reshape(1, -1)
        Qs0a.append(Qfunctions[i].predict(s0a))
    Vs0[i] = np.max(Qs0a)
plt.plot(Vs0)

# Bellman residual
residual = []
for i in range(1,nb_iter):
    residual.append(np.mean((Qfunctions[i].predict(SA)-Qfunctions[i-1].predict(SA))**2))
plt.figure()
plt.plot(residual);

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Evaluate graphically and qualitatively how the last learned policy performs.
# </div>

# %%
def greedy_action(Q,s,nb_actions):
    Qsa = []
    for a in range(nb_actions):
        sa = np.append(s,a).reshape(1, -1)
        Qsa.append(Q.predict(sa))
    return np.argmax(Qsa)

# %%
import gymnasium as gym
cartpole = gym.make('CartPole-v1', render_mode="human")
s,_ = cartpole.reset()
for t in range(500):
    a = greedy_action(Qfunctions[-1],s,cartpole.action_space.n)
    s2,r,d,trunc,_ = cartpole.step(a)
    cartpole.render()
    s = s2
    if d:
        break

# %%
cartpole.close()

# %% [markdown]
# ## Discussion
#
# Eventually, we have a fully offline procedure that seems to achieve an efficient control for the cart-pole (or acrobot) environment. This is a rather strong result: with fully offline samples we seem to be able to learn good controlers.
#
# But there are limits to this approach, mostly due to the mismatch between $\rho$ and the states and actions actually visited by the learned policy $\pi$.
# What would have happened if, in acrobot, there had been no sample with `done=True` in the training set?
# Isn't the totally random collection of samples a waste of computational resources in some states, and a lack of exploration in others?
#
# Some samples in the training set might be very redundant or completely unrelated to states encountered by $\pi$. Their presence in the training set biases the loss. Additionally, collecting them did cost us some computing time, which might have been better used.
# Conversely, some states and actions visited by $\pi$ might be absent from the support of $\rho$. Because of this, there are no good estimates of $Q(s,a)$ obtained from the training set, which prevent actually incrementally improving $\pi$.
# We discussed this in the previous chapter when we covered the importance of the behavior distribution.
#
# A simple empirical fix to this problem would be to enrich the training set incrementally, by performing rounds of data collection at every iteration of FQI, collecting samples from $(s,a)$ pairs seen by $\pi_n$ and also exploring new actions is the corresponding states $s$.
#
# We won't implement this now and turn to a more online procedure. However, note that offline RL received a lot of attention and analysis in recent years and is still a very active field of research.

# %% [markdown]
# # Neural networks for AVI: deep Q-networks

# %% [markdown]
# ## Back to AVI as a series of risk minimization problems
#
# Again, let us return to the original formulation of AVI as a sequence of supervised learning problems.
#
# <div class="alert alert-success">
#
# **Approximate value iteration as a sequence of risk minimization problems**
# $$\pi_n \in \mathcal{G} Q_n,$$
# $$L_n(\theta) = \frac{1}{2} \mathbb{E}_{(s,a) \sim \rho}\left[ \left( Q(s,a;\theta) - G^{\pi_n}_1(s,a,Q_n) \right)^2 \right],$$
# $$\theta_{n+1} \in \arg\min_{\theta} L_n(\theta),$$
# $$Q_{n+1}(s,a) = Q(s,a;\theta_{n+1}).$$
# </div>
#
# With
# $$\pi \in \mathcal{G} Q, \Leftrightarrow \pi(s) \in \arg\max_{\pi \in \Delta_A} \mathbb{E}_{a\sim\pi} \left[Q(s,a)\right]$$
#
# And
# $$G^\pi_1(s,a,Q) = R_0 + \gamma Q(S_1, A_1) \quad \Bigg| \quad \begin{array}{l}S_0 = s, A_0=a\\ A_1 \sim \pi(S_1),\\ S_{1}\sim p(\cdot|S_0,A_0),\\ R_0 = r(S_0,A_0,S_{1}).\end{array}$$
#
# If this risk is differentiable, ie. if $Q$ is differentiable with respect to $\theta$, provided one can draw a mini-batch of independently and identically drawn samples $\left\{\left(s_i,a_i,r_i,s'_i\right)\right\}_{i\in [1,B]}$ (either by sampling from a larger training set, or directly from the system to control), with $(s,a) \sim \rho(\cdot)$ and $s',a' \sim p(s' | s,a)\pi(a'|s')$, then one can derive a stochastic gradient descent learning procedure and iteratively learn $\theta_{n+1}$ as the limit of the sequence $\theta_{k+1} \leftarrow \theta_{k} + \alpha_k d_n(\theta_{k})$ with
# $$d_n(\theta) = \frac{1}{B} \sum_{i=1}^B \left[ \left( r_i + \gamma Q(s_i',\pi_n(s'_i);\theta_{n}) - Q(s_i,a_i;\theta) \right) \nabla_\theta Q(s_i,a_i;\theta) \right].$$
#
# This type of SGD optimization is precisely what is done in neural networks optimization.

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Do you recall what are the differences with Q-learning?
# </div>

# %% [markdown]
# <details class="alert alert-danger">
#     <summary markdown="span"><b>Ready to see the answer? (click to expand)</b></summary>
#
# In Q-learning, there was no training set and the samples were collected on-the-fly.
# So $B=1$.
# But also, two consecutive samples were higly correlated, breaking the iid assumption.
# </details>

# %% [markdown]
# ## Experience Replay
#
# To recover the independence assumption between samples, we can, as previously, introduce the mechanism of [*Experience Replay*](https://link.springer.com/article/10.1007/BF00992699) by storing past samples into a *Replay Memory*. When samples a required for a mini-batch gradient update, the samples are collected uniformly from the replay memory, thus mimicking an (almost) independent draw according to $\rho(\cdot)$.

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Design a class for storing and sampling experience samples. Limit the size of this memory (via a FIFO mechanism) to a fixed number of samples (adapt this number to your computer's RAM). Test it by running a random policy for $2\cdot 10^6$ time steps.
# </div>

# %%
# %load solutions/replay_buffer.py
import random

class ReplayBuffer:
    def __init__(self, capacity):
        self.capacity = capacity # capacity of the buffer
        self.data = []
        self.index = 0 # index of the next cell to be filled
    def append(self, s, a, r, s_, d):
        if len(self.data) < self.capacity:
            self.data.append(None)
        self.data[self.index] = (s, a, r, s_, d)
        self.index = (self.index + 1) % self.capacity
    def sample(self, batch_size):
        return random.sample(self.data, batch_size)
    def __len__(self):
        return len(self.data)

# %%
# Testing insertion in the ReplayBuffer class
from tqdm import trange
import gymnasium as gym
cartpole = gym.make('CartPole-v1', render_mode="rgb_array")
replay_buffer_size = int(1e6)
nb_samples = int(2e6)

memory = ReplayBuffer(replay_buffer_size)
state, _ = cartpole.reset()
print("Testing insertion of", nb_samples, "samples in the replay buffer")
for _ in trange(nb_samples):
    action = cartpole.action_space.sample()
    next_state, reward, done, trunc, _ = cartpole.step(action)
    memory.append(state, action, reward, next_state, done)
    if done:
        state, _ = cartpole.reset()
    else:
        state = next_state

print("Replay buffer size:", len(memory))

# Testing sampling in the ReplayBuffer class
nb_batches = int(1e4)
batch_size = 50
import random

print("Testing sampling of", nb_batches, "minibatches of size", batch_size, "from the replay buffer")
for _ in trange(nb_batches):
    batch = memory.sample(batch_size)

print("Example of a 2-sample minibatch", memory.sample(2))

# %% [markdown]
# <div class="alert alert-warning">
#
# **Know your data structures!**
#
# Taking some time to think about what makes a good replay buffer may save you hours of puzzled head-banging. It is important to know what you expect from your replay buffer to choose the right data structure.
#
# Common mistake: we need a fixed sized memory, that works like a FIFO structure, so let's pick a [deque](https://docs.python.org/3/library/collections.html#collections.deque) (double-ended queue). That sounds fair, deques (in Python) have a fixed maximum size and constant time insertion at the beginning and the end. BUT they also have [$O(n)$ access time](https://wiki.python.org/moin/TimeComplexity) which means that for large replay buffers, sampling a minibatch may take forever.
#
# Here, what we really need is a fixed-size FIFO, with $O(1)$ insertion at the end and $O(1)$ access.
#
# This should motivate the choices made in the replay buffer class above.
#
# If you want empirical verification of the reasoning above, in the "replay memory" folder, you will find a short notebook enabling empirical testing of many different data structures for replay buffers.
# </div>

# %% [markdown]
# ## A deep Q-network
#
# The term Deep Q-Network was coined by the (now historical) paper **[Playing Atari with Deep Reinforcement Learning](https://arxiv.org/abs/1312.5602)** by Mnih et al. (2013) that put forward the main ideas we develop here. All those were later popularized by DeepMind's paper in Nature **[Human-level control through deep reinforcement learning](https://deepmind.com/research/publications/human-level-control-through-deep-reinforcement-learning)** by Mnih et al. (2015).
#
# Let's design a (deep) neural network that will serve as a function approximator for $Q(s,a;\theta)$.
#
# <center><img src="img/dqlas.png" height="15%" width="15%"></img></center>
#
# Note that since we're going to have to compute $\max_a Q(s,a)$ and since actions are discrete, it is preferable to avoid running as many passes through the network as there are actions. Therefore, instead of the network structure above, we will prefer to use the one below.
#
# <center><img src="img/dqls.png" height="30%" width="30%"></img></center>

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Declare a simple neural network for our $Q$ function with 2 hidden layers and 24 neurons on each layer.
# </div>

# %%
import torch
import torch.nn as nn
import gymnasium as gym
cartpole = gym.make('CartPole-v1', render_mode="rgb_array")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

state_dim = cartpole.observation_space.shape[0]
n_action = cartpole.action_space.n 
nb_neurons=24

DQN = torch.nn.Sequential(nn.Linear(state_dim, nb_neurons),
                          nn.ReLU(),
                          nn.Linear(nb_neurons, nb_neurons),
                          nn.ReLU(), 
                          nn.Linear(nb_neurons, n_action)).to(device)

# %% [markdown]
# We're almost there. Now we can implement the algorithm that:
# - takes $\epsilon$-greedy actions with respect to $Q$
# - stores samples in the replay buffer
# - at each interaction step with the environment, draws a mini-batch, computes the target values for each $(s,a)$ and takes a gradient step.
# - repeats

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Write this algorithm's pseudo-code.
# You can take inspiration from the algorithm on page 5 of **[Playing Atari with Deep Reinforcement Learning](https://arxiv.org/abs/1312.5602)**.
# </div>

# %% [markdown]
# <details class="alert alert-danger">
#     <summary markdown="span"><b>Ready to see the answer? (click to expand)</b></summary>
#
#          state = init()
#          loop:
#             action = greedy_action(DQN) or random_action()
#             new_state, reward = step(state, action)
#             replay_memory.add(state, action, reward, new_state)
#             minibatch = replay_memory.sample(minibatch_size)
#             X_train = Y_train = []
#             for (s,a,r,s') in minibatch:
#                 Q  = DQN.predict(s)
#                 Q' = DQN.predict(s')
#                 if non-terminal(s'):
#                     update = r + gamma * max(Q')
#                 else:
#                     update = r
#                 Q[a] = update
#                 X_train.append(s)
#                 Y_train.append(Q)
#             DQN.train_one_step(X_train,Y_train)
#             state = new_state
# </details>

# %% [markdown]
# Now we can proceed with the implementation. This series of exercises break it down into small steps.
#
# <div class="alert alert-warning">
#
# **Exercise:**
# It will actually be useful to have separate torch.Tensor for the each element type in the sampled minibatch.
# That is one Tensor for a minibatch of states, another for actions, etc.
# Let's redefine the sample function of our replay buffer class to that end.
# </div>

# %%
# %load solutions/replay_buffer2.py
import random
import torch

class ReplayBuffer:
    def __init__(self, capacity, device):
        self.capacity = capacity # capacity of the buffer
        self.data = []
        self.index = 0 # index of the next cell to be filled
        self.device = device
    def append(self, s, a, r, s_, d):
        if len(self.data) < self.capacity:
            self.data.append(None)
        self.data[self.index] = (s, a, r, s_, d)
        self.index = (self.index + 1) % self.capacity
    def sample(self, batch_size):
        batch = random.sample(self.data, batch_size)
        return list(map(lambda x:torch.Tensor(np.array(x)).to(self.device), list(zip(*batch))))
    def __len__(self):
        return len(self.data)

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Define a utility function that computes the greedy action from a DQN and a batch of states.
# </div>

# %%
# %load solutions/dqn_greedy_action.py
import torch

def greedy_action(network, state):
    device = "cuda" if next(network.parameters()).is_cuda else "cpu"
    with torch.no_grad():
        Q = network(torch.Tensor(state).unsqueeze(0).to(device))
        return torch.argmax(Q).item()

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Write a class that keeps a replay buffer as internal attribute and implements the pseudo-code you wrote earlier.
# Here are a few tips:
# - To ensure exploration, take a constant $\epsilon_{max}$ value during $\tau_{delay}$ time steps, then substract $\epsilon_{step}$ from $\epsilon$ at every time step until you reach time $\tau_{period}$.
# - A common optimizer (instead of plain SGD) is ADAM (or RMSprop).
# - Assume the interaction with the environment will be episodic. After each training episode store the episode's cumulated return for monitoring.
#
# Write your class but don't run this code just yet!
# </div>

# %%
import numpy as np
import torch
import torch.nn as nn
from solutions.replay_buffer2 import ReplayBuffer
from solutions.dqn_greedy_action import greedy_action

class dqn_agent:
    def __init__(self, config, model):
        device = "cuda" if next(model.parameters()).is_cuda else "cpu"
        self.gamma = config['gamma']
        self.batch_size = config['batch_size']
        self.nb_actions = config['nb_actions']
        self.memory = ReplayBuffer(config['buffer_size'], device)
        self.epsilon_max = config['epsilon_max']
        self.epsilon_min = config['epsilon_min']
        self.epsilon_stop = config['epsilon_decay_period']
        self.epsilon_delay = config['epsilon_delay_decay']
        self.epsilon_step = (self.epsilon_max-self.epsilon_min)/self.epsilon_stop
        self.model = model 
        self.criterion = torch.nn.MSELoss()
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=config['learning_rate'])
    
    def gradient_step(self):
        if len(self.memory) > self.batch_size:
            X, A, R, Y, D = self.memory.sample(self.batch_size)
            QYmax = self.model(Y).max(1)[0].detach()
            #update = torch.addcmul(R, self.gamma, 1-D, QYmax)
            update = torch.addcmul(R, 1-D, QYmax, value=self.gamma)
            QXA = self.model(X).gather(1, A.to(torch.long).unsqueeze(1))
            loss = self.criterion(QXA, update.unsqueeze(1))
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step() 
    
    def train(self, env, max_episode):
        episode_return = []
        episode = 0
        episode_cum_reward = 0
        state, _ = env.reset()
        epsilon = self.epsilon_max
        step = 0

        while episode < max_episode:
            # update epsilon
            if step > self.epsilon_delay:
                epsilon = max(self.epsilon_min, epsilon-self.epsilon_step)

            # select epsilon-greedy action
            if np.random.rand() < epsilon:
                action = env.action_space.sample()
            else:
                action = greedy_action(self.model, state)

            # step
            next_state, reward, done, trunc, _ = env.step(action)
            self.memory.append(state, action, reward, next_state, done)
            episode_cum_reward += reward

            # train
            self.gradient_step()

            # next transition
            step += 1
            if done:
                episode += 1
                print("Episode ", '{:3d}'.format(episode), 
                      ", epsilon ", '{:6.2f}'.format(epsilon), 
                      ", batch size ", '{:5d}'.format(len(self.memory)), 
                      ", episode return ", '{:4.1f}'.format(episode_cum_reward),
                      sep='')
                state, _ = env.reset()
                episode_return.append(episode_cum_reward)
                episode_cum_reward = 0
            else:
                state = next_state

        return episode_return

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Train for 200 episodes on CartPole, with a learning rate of $0.001$, abatch size of $20$, $\gamma=0.95$ and a replay buffer of maximum $1000000$ samples. Take $\epsilon_{max}=1$, $\epsilon_{min}=0.01$, $\tau_{delay}=20$ and $\tau_{period}=1000$.
# </div>

# %%
import gymnasium as gym
cartpole = gym.make('CartPole-v1', render_mode="rgb_array")
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Declare network
state_dim = cartpole.observation_space.shape[0]
n_action = cartpole.action_space.n 
nb_neurons=24
DQN = torch.nn.Sequential(nn.Linear(state_dim, nb_neurons),
                          nn.ReLU(),
                          nn.Linear(nb_neurons, nb_neurons),
                          nn.ReLU(), 
                          nn.Linear(nb_neurons, n_action)).to(device)

# DQN config
config = {'observation_space': cartpole.observation_space.shape[0],
          'nb_actions': cartpole.action_space.n,
          'learning_rate': 0.001,
          'gamma': 0.95,
          'buffer_size': 1000000,
          'epsilon_min': 0.01,
          'epsilon_max': 1.,
          'epsilon_decay_period': 1000,
          'epsilon_delay_decay': 20,
          'batch_size': 20}

# Train agent
agent = dqn_agent(config, DQN)
scores = agent.train(cartpole, 200)
plt.plot(scores)
# Out:
# Episode   1, epsilon   1.00, batch size    23, episode return 23.0
# Episode   2, epsilon   0.96, batch size    65, episode return 42.0
# Episode   3, epsilon   0.94, batch size    80, episode return 15.0
# Episode   4, epsilon   0.92, batch size    97, episode return 17.0
# Episode   5, epsilon   0.90, batch size   119, episode return 22.0
# Episode   6, epsilon   0.88, batch size   143, episode return 24.0
# Episode   7, epsilon   0.84, batch size   186, episode return 43.0
# Episode   8, epsilon   0.82, batch size   201, episode return 15.0
# Episode   9, epsilon   0.80, batch size   225, episode return 24.0
# Episode  10, epsilon   0.78, batch size   246, episode return 21.0
# Episode  11, epsilon   0.76, batch size   259, episode return 13.0
# Episode  12, epsilon   0.75, batch size   276, episode return 17.0
# Episode  13, epsilon   0.73, batch size   289, episode return 13.0
# Episode  14, epsilon   0.72, batch size   308, episode return 19.0
# Episode  15, epsilon   0.70, batch size   319, episode return 11.0
# Episode  16, epsilon   0.69, batch size   337, episode return 18.0
# Episode  17, epsilon   0.66, batch size   364, episode return 27.0
# Episode  18, epsilon   0.64, batch size   381, episode return 17.0
# Episode  19, epsilon   0.63, batch size   395, episode return 14.0
# Episode  20, epsilon   0.60, batch size   421, episode return 26.0
# Episode  21, epsilon   0.59, batch size   432, episode return 11.0
# Episode  22, epsilon   0.58, batch size   445, episode return 13.0
# Episode  23, epsilon   0.57, batch size   458, episode return 13.0
# Episode  24, epsilon   0.55, batch size   471, episode return 13.0
# Episode  25, epsilon   0.54, batch size   483, episode return 12.0
# Episode  26, epsilon   0.53, batch size   496, episode return 13.0
# Episode  27, epsilon   0.52, batch size   506, episode return 10.0
# Episode  28, epsilon   0.51, batch size   519, episode return 13.0
# Episode  29, epsilon   0.50, batch size   530, episode return 11.0
# Episode  30, epsilon   0.48, batch size   547, episode return 17.0
# Episode  31, epsilon   0.47, batch size   560, episode return 13.0
# Episode  32, epsilon   0.46, batch size   569, episode return  9.0
# Episode  33, epsilon   0.44, batch size   590, episode return 21.0
# Episode  34, epsilon   0.43, batch size   600, episode return 10.0
# Episode  35, epsilon   0.41, batch size   612, episode return 12.0
# Episode  36, epsilon   0.41, batch size   622, episode return 10.0
# Episode  37, epsilon   0.38, batch size   644, episode return 22.0
# Episode  38, epsilon   0.36, batch size   663, episode return 19.0
# Episode  39, epsilon   0.35, batch size   681, episode return 18.0
# Episode  40, epsilon   0.33, batch size   699, episode return 18.0
# Episode  41, epsilon   0.31, batch size   717, episode return 18.0
# Episode  42, epsilon   0.30, batch size   733, episode return 16.0
# Episode  43, epsilon   0.28, batch size   747, episode return 14.0
# Episode  44, epsilon   0.27, batch size   763, episode return 16.0
# Episode  45, epsilon   0.25, batch size   776, episode return 13.0
# Episode  46, epsilon   0.23, batch size   803, episode return 27.0
# Episode  47, epsilon   0.19, batch size   835, episode return 32.0
# Episode  48, epsilon   0.17, batch size   856, episode return 21.0
# Episode  49, epsilon   0.15, batch size   881, episode return 25.0
# Episode  50, epsilon   0.11, batch size   915, episode return 34.0
# Episode  51, epsilon   0.09, batch size   944, episode return 29.0
# Episode  52, epsilon   0.05, batch size   977, episode return 33.0
# Episode  53, epsilon   0.01, batch size  1048, episode return 71.0
# Episode  54, epsilon   0.01, batch size  1079, episode return 31.0
# Episode  55, epsilon   0.01, batch size  1105, episode return 26.0
# Episode  56, epsilon   0.01, batch size  1147, episode return 42.0
# Episode  57, epsilon   0.01, batch size  1178, episode return 31.0
# Episode  58, epsilon   0.01, batch size  1242, episode return 64.0
# Episode  59, epsilon   0.01, batch size  1287, episode return 45.0
# Episode  60, epsilon   0.01, batch size  1318, episode return 31.0
# Episode  61, epsilon   0.01, batch size  1383, episode return 65.0
# Episode  62, epsilon   0.01, batch size  1414, episode return 31.0
# Episode  63, epsilon   0.01, batch size  1440, episode return 26.0
# Episode  64, epsilon   0.01, batch size  1485, episode return 45.0
# Episode  65, epsilon   0.01, batch size  1520, episode return 35.0
# Episode  66, epsilon   0.01, batch size  1622, episode return 102.0
# Episode  67, epsilon   0.01, batch size  1669, episode return 47.0
# Episode  68, epsilon   0.01, batch size  1714, episode return 45.0
# Episode  69, epsilon   0.01, batch size  1758, episode return 44.0
# Episode  70, epsilon   0.01, batch size  1912, episode return 154.0
# Episode  71, epsilon   0.01, batch size  1981, episode return 69.0
# Episode  72, epsilon   0.01, batch size  2055, episode return 74.0
# Episode  73, epsilon   0.01, batch size  2115, episode return 60.0
# Episode  74, epsilon   0.01, batch size  2182, episode return 67.0
# Episode  75, epsilon   0.01, batch size  2238, episode return 56.0
# Episode  76, epsilon   0.01, batch size  2389, episode return 151.0
# Episode  77, epsilon   0.01, batch size  2504, episode return 115.0
# Episode  78, epsilon   0.01, batch size  2679, episode return 175.0
# Episode  79, epsilon   0.01, batch size  2808, episode return 129.0
# Episode  80, epsilon   0.01, batch size  2962, episode return 154.0
# Episode  81, epsilon   0.01, batch size  3085, episode return 123.0
# Episode  82, epsilon   0.01, batch size  3197, episode return 112.0
# Episode  83, epsilon   0.01, batch size  3323, episode return 126.0
# Episode  84, epsilon   0.01, batch size  3382, episode return 59.0
# Episode  85, epsilon   0.01, batch size  3457, episode return 75.0
# Episode  86, epsilon   0.01, batch size  3547, episode return 90.0
# Episode  87, epsilon   0.01, batch size  3666, episode return 119.0
# Episode  88, epsilon   0.01, batch size  3800, episode return 134.0
# Episode  89, epsilon   0.01, batch size  3863, episode return 63.0
# Episode  90, epsilon   0.01, batch size  3946, episode return 83.0
# Episode  91, epsilon   0.01, batch size  4012, episode return 66.0
# Episode  92, epsilon   0.01, batch size  4071, episode return 59.0
# Episode  93, epsilon   0.01, batch size  4188, episode return 117.0
# Episode  94, epsilon   0.01, batch size  4300, episode return 112.0
# Episode  95, epsilon   0.01, batch size  4461, episode return 161.0
# Episode  96, epsilon   0.01, batch size  4524, episode return 63.0
# Episode  97, epsilon   0.01, batch size  4578, episode return 54.0
# Episode  98, epsilon   0.01, batch size  4651, episode return 73.0
# Episode  99, epsilon   0.01, batch size  4766, episode return 115.0
# Episode 100, epsilon   0.01, batch size  4943, episode return 177.0
# Episode 101, epsilon   0.01, batch size  5053, episode return 110.0
# Episode 102, epsilon   0.01, batch size  5226, episode return 173.0
# Episode 103, epsilon   0.01, batch size  5406, episode return 180.0
# Episode 104, epsilon   0.01, batch size  5539, episode return 133.0
# Episode 105, epsilon   0.01, batch size  5678, episode return 139.0
# Episode 106, epsilon   0.01, batch size  5821, episode return 143.0
# Episode 107, epsilon   0.01, batch size  5973, episode return 152.0
# Episode 108, epsilon   0.01, batch size  6189, episode return 216.0
# Episode 109, epsilon   0.01, batch size  6421, episode return 232.0
# Episode 110, epsilon   0.01, batch size  6559, episode return 138.0
# Episode 111, epsilon   0.01, batch size  6700, episode return 141.0
# Episode 112, epsilon   0.01, batch size  6824, episode return 124.0
# Episode 113, epsilon   0.01, batch size  6982, episode return 158.0
# Episode 114, epsilon   0.01, batch size  7126, episode return 144.0
# Episode 115, epsilon   0.01, batch size  7264, episode return 138.0
# Episode 116, epsilon   0.01, batch size  7403, episode return 139.0
# Episode 117, epsilon   0.01, batch size  7570, episode return 167.0
# Episode 118, epsilon   0.01, batch size  7762, episode return 192.0
# Episode 119, epsilon   0.01, batch size  7912, episode return 150.0
# Episode 120, epsilon   0.01, batch size  8044, episode return 132.0
# Episode 121, epsilon   0.01, batch size  8172, episode return 128.0
# Episode 122, epsilon   0.01, batch size  8323, episode return 151.0
# Episode 123, epsilon   0.01, batch size  8458, episode return 135.0
# Episode 124, epsilon   0.01, batch size  8584, episode return 126.0
# Episode 125, epsilon   0.01, batch size  8713, episode return 129.0
# Episode 126, epsilon   0.01, batch size  8859, episode return 146.0
# Episode 127, epsilon   0.01, batch size  9003, episode return 144.0
# Episode 128, epsilon   0.01, batch size  9147, episode return 144.0
# Episode 129, epsilon   0.01, batch size  9296, episode return 149.0
# Episode 130, epsilon   0.01, batch size  9498, episode return 202.0
# Episode 131, epsilon   0.01, batch size  9653, episode return 155.0
# Episode 132, epsilon   0.01, batch size  9802, episode return 149.0
# Episode 133, epsilon   0.01, batch size  9940, episode return 138.0
# Episode 134, epsilon   0.01, batch size 10090, episode return 150.0
# Episode 135, epsilon   0.01, batch size 10223, episode return 133.0
# Episode 136, epsilon   0.01, batch size 10365, episode return 142.0
# Episode 137, epsilon   0.01, batch size 10486, episode return 121.0
# Episode 138, epsilon   0.01, batch size 10631, episode return 145.0
# Episode 139, epsilon   0.01, batch size 10795, episode return 164.0
# Episode 140, epsilon   0.01, batch size 10934, episode return 139.0
# Episode 141, epsilon   0.01, batch size 11106, episode return 172.0
# Episode 142, epsilon   0.01, batch size 11266, episode return 160.0
# Episode 143, epsilon   0.01, batch size 11409, episode return 143.0
# Episode 144, epsilon   0.01, batch size 11536, episode return 127.0
# Episode 145, epsilon   0.01, batch size 11693, episode return 157.0
# Episode 146, epsilon   0.01, batch size 11828, episode return 135.0
# Episode 147, epsilon   0.01, batch size 12034, episode return 206.0
# Episode 148, epsilon   0.01, batch size 12171, episode return 137.0
# Episode 149, epsilon   0.01, batch size 12300, episode return 129.0
# Episode 150, epsilon   0.01, batch size 12436, episode return 136.0
# Episode 151, epsilon   0.01, batch size 12573, episode return 137.0
# Episode 152, epsilon   0.01, batch size 12721, episode return 148.0
# Episode 153, epsilon   0.01, batch size 12882, episode return 161.0
# Episode 154, epsilon   0.01, batch size 13032, episode return 150.0
# Episode 155, epsilon   0.01, batch size 13222, episode return 190.0
# Episode 156, epsilon   0.01, batch size 13358, episode return 136.0
# Episode 157, epsilon   0.01, batch size 13490, episode return 132.0
# Episode 158, epsilon   0.01, batch size 13645, episode return 155.0
# Episode 159, epsilon   0.01, batch size 13772, episode return 127.0
# Episode 160, epsilon   0.01, batch size 14108, episode return 336.0
# Episode 161, epsilon   0.01, batch size 14244, episode return 136.0
# Episode 162, epsilon   0.01, batch size 14378, episode return 134.0
# Episode 163, epsilon   0.01, batch size 14508, episode return 130.0
# Episode 164, epsilon   0.01, batch size 14635, episode return 127.0
# Episode 165, epsilon   0.01, batch size 14784, episode return 149.0
# Episode 166, epsilon   0.01, batch size 14941, episode return 157.0
# Episode 167, epsilon   0.01, batch size 15074, episode return 133.0
# Episode 168, epsilon   0.01, batch size 15207, episode return 133.0
# Episode 169, epsilon   0.01, batch size 15353, episode return 146.0
# Episode 170, epsilon   0.01, batch size 15479, episode return 126.0
# Episode 171, epsilon   0.01, batch size 15611, episode return 132.0
# Episode 172, epsilon   0.01, batch size 15760, episode return 149.0
# Episode 173, epsilon   0.01, batch size 15944, episode return 184.0
# Episode 174, epsilon   0.01, batch size 16095, episode return 151.0
# Episode 175, epsilon   0.01, batch size 16247, episode return 152.0
# Episode 176, epsilon   0.01, batch size 16394, episode return 147.0
# Episode 177, epsilon   0.01, batch size 16520, episode return 126.0
# Episode 178, epsilon   0.01, batch size 16666, episode return 146.0
# Episode 179, epsilon   0.01, batch size 16825, episode return 159.0
# Episode 180, epsilon   0.01, batch size 16998, episode return 173.0
# Episode 181, epsilon   0.01, batch size 17164, episode return 166.0
# Episode 182, epsilon   0.01, batch size 17317, episode return 153.0
# Episode 183, epsilon   0.01, batch size 17465, episode return 148.0
# Episode 184, epsilon   0.01, batch size 17604, episode return 139.0
# Episode 185, epsilon   0.01, batch size 17770, episode return 166.0
# Episode 186, epsilon   0.01, batch size 17913, episode return 143.0
# Episode 187, epsilon   0.01, batch size 18058, episode return 145.0
# Episode 188, epsilon   0.01, batch size 18192, episode return 134.0
# Episode 189, epsilon   0.01, batch size 18366, episode return 174.0
# Episode 190, epsilon   0.01, batch size 18510, episode return 144.0
# Episode 191, epsilon   0.01, batch size 18654, episode return 144.0
# Episode 192, epsilon   0.01, batch size 18807, episode return 153.0
# Episode 193, epsilon   0.01, batch size 18941, episode return 134.0
# Episode 194, epsilon   0.01, batch size 19086, episode return 145.0
# Episode 195, epsilon   0.01, batch size 19233, episode return 147.0
# Episode 196, epsilon   0.01, batch size 19379, episode return 146.0
# Episode 197, epsilon   0.01, batch size 19522, episode return 143.0
# Episode 198, epsilon   0.01, batch size 19676, episode return 154.0
# Episode 199, epsilon   0.01, batch size 19818, episode return 142.0
# Episode 200, epsilon   0.01, batch size 19984, episode return 166.0

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Observe how the learned policy behaves.
# </div>

# %%
import gymnasium as gym
from solutions.dqn_greedy_action import greedy_action

cartpole = gym.make('CartPole-v1', render_mode="human")
s,_ = cartpole.reset()
for t in range(1000):
    a = greedy_action(DQN,s)
    s2,r,d,trunc,_ = cartpole.step(a)
    cartpole.render()
    s = s2
    if d:
        break

cartpole.close()

# %% [markdown]
# ## Target networks
#
# Let's take a step back. In the end, we have done something quite similar to Q-learning: at every iteration of AVI, the $Q_{n+1} = \mathcal{A}T^* Q_n$ we compute is obtained by taking a single gradient step in the direction of $T^* Q_n$. This enabled having a single network in memory, and using it to bootstrap its own training samples.
#
# A single gradient step makes for a poor function approximator. In turn, the sequence of $Q_n$ functions might be quite unstable and noisy, in particular with environments that have large variance in $s'$ and $r$ (which is not the case for the cart-pole environment). This can be greatly improved by taking several gradient steps on a given loss function $L_n$, instead of taking a single step and changing the loss function after each sample. This idea is the same as that of delayed updates that we introduced in the chapter on temporal difference learning.
#
# So, instead of having a single network, we wish to keep $Q_n$ in memory so that we can refine our approximation $Q_{n+1}$.
#
# In practice, this is achieved by the introduction of a *target network* whose parameters are noted $\theta^-$, and who plays the role of $Q_n$ when learning $Q_{n+1}$.
# Surprisingly and despite its straightforward roots in AVI, this idea was not implemented in the 2013 **[Playing Atari with Deep Reinforcement Learning](https://arxiv.org/abs/1312.5602)** paper which introduced DQN. One had to wait for the 2015 **[Human-level control through deep reinforcement learning](https://deepmind.com/research/publications/human-level-control-through-deep-reinforcement-learning)** paper to see the introduction of target networks. So the loss of DQN with a target network is:
# $$L(\theta) = \mathbb{E}_{s,a,r,s'} \left[ \left( r + \gamma \max_{a'} Q(s',a',\theta^-) - Q(s,a;\theta) \right) ^2 \right],$$
# and the target network parameters $\theta^-$ are only updated with the Q-network parameters $\theta_n$ every $C$ steps and are held fixed between individual updates.
#
# Note that more recent approaches smooth out this accumulation process by defining an exponential moving average update at every time step, of the form:
# $$\theta^- \leftarrow \tau \theta + (1-\tau) \theta^-.$$

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Is this the same thing as taking several gradient steps after each sample?
# </div>

# %% [markdown]
# <details class="alert alert-danger">
#     <summary markdown="span"><b>Ready to see the answer? (click to expand)</b></summary>
#
# Beware, here be dragons!
#
# No, this is not the same thing. At all.
# By synchronizing gradient steps, we make sure the replay buffer always tracks the behavior distribution of the current policy. That is: the replay buffer features samples that correspond to trying greedy or exploratory actions in states which are likely to be encountered, and hence, it contains crucial information for policy improvement.
#
# Here, by using target networks, we don't break this synchronization. We retain it as we update $\theta$. We simply allow $Q_\theta$ to better fit $T^* Q_n$ before we move on to the next iteration of AVI.
#
# Conversely, taking several gradient steps on $L_n$ without collecting new data implies taking the risk that the behavior policy's state distribution drifts away from the replay buffer's empirical distribution. In turn, this leads to the risk that gradient updates after the first one are ill-informed. In very easy environments (eg. when state space coverage is rather easy to achieve, like in cart-pole), this can be benign and go unnoticed. But beware: in many difficult situations (eg. when the environment is difficult to explore, when stochasticity is high, when state distributions change quickly with parameter updates, etc.) this can quickly lead to policies that make no sense and eventually perform really badly.
#
# An interesting analysis of this dependency can be found in the **[The Difficulty of Passive Learning in Deep Reinforcement Learning](https://openreview.net/forum?id=nPHA8fGicZk)** paper by Ostrovski et al. (2021).
# </details>

# %% [markdown]
# ## Losses and optimizers
#
# It might seem trivial, but the question of which optimizer to choose is quite open in RL. Most common choices are RMSprop or Adam (with, sometimes, carefully chosen hyperparameters). For the example of CartPole, it seems Adam with default parameters works better, but that's not a general rule.
#
# Another common pratice to stabilize learning is to clip the value of the loss' gradient between $-1$ and $1$. This is not such an uncommon trick, it actually amounts to using an L2 loss for values of the loss between $-1$ and $1$ and an L1 loss outside of this domain. This is also know as the [Huber Loss](https://en.wikipedia.org/wiki/Huber_loss) or the [smooth L1 loss](https://pytorch.org/docs/stable/nn.html#smoothl1loss).

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise:**
# Modify the previous `dqn_agent` class to include a target network, with an option to perform periodic updates or moving average updates, the possibility to take several gradient steps after each sample, and options for choosing the loss and the optimizer.
# </div>

# %%
# %load solutions/dqn_agent.py
import numpy as np
import torch
import torch.nn as nn
from copy import deepcopy
from solutions.replay_buffer2 import ReplayBuffer
from solutions.dqn_greedy_action import greedy_action

class dqn_agent:
    def __init__(self, config, model):
        device = "cuda" if next(model.parameters()).is_cuda else "cpu"
        self.nb_actions = config['nb_actions']
        self.gamma = config['gamma'] if 'gamma' in config.keys() else 0.95
        self.batch_size = config['batch_size'] if 'batch_size' in config.keys() else 100
        buffer_size = config['buffer_size'] if 'buffer_size' in config.keys() else int(1e5)
        self.memory = ReplayBuffer(buffer_size,device)
        self.epsilon_max = config['epsilon_max'] if 'epsilon_max' in config.keys() else 1.
        self.epsilon_min = config['epsilon_min'] if 'epsilon_min' in config.keys() else 0.01
        self.epsilon_stop = config['epsilon_decay_period'] if 'epsilon_decay_period' in config.keys() else 1000
        self.epsilon_delay = config['epsilon_delay_decay'] if 'epsilon_delay_decay' in config.keys() else 20
        self.epsilon_step = (self.epsilon_max-self.epsilon_min)/self.epsilon_stop
        self.model = model 
        self.target_model = deepcopy(self.model).to(device)
        self.criterion = config['criterion'] if 'criterion' in config.keys() else torch.nn.MSELoss()
        lr = config['learning_rate'] if 'learning_rate' in config.keys() else 0.001
        self.optimizer = config['optimizer'] if 'optimizer' in config.keys() else torch.optim.Adam(self.model.parameters(), lr=lr)
        self.nb_gradient_steps = config['gradient_steps'] if 'gradient_steps' in config.keys() else 1
        self.update_target_strategy = config['update_target_strategy'] if 'update_target_strategy' in config.keys() else 'replace'
        self.update_target_freq = config['update_target_freq'] if 'update_target_freq' in config.keys() else 20
        self.update_target_tau = config['update_target_tau'] if 'update_target_tau' in config.keys() else 0.005
    
    def gradient_step(self):
        if len(self.memory) > self.batch_size:
            X, A, R, Y, D = self.memory.sample(self.batch_size)
            QYmax = self.target_model(Y).max(1)[0].detach()
            update = torch.addcmul(R, self.gamma, 1-D, QYmax)
            QXA = self.model(X).gather(1, A.to(torch.long).unsqueeze(1))
            loss = self.criterion(QXA, update.unsqueeze(1))
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step() 
    
    def train(self, env, max_episode):
        episode_return = []
        episode = 0
        episode_cum_reward = 0
        state, _ = env.reset()
        epsilon = self.epsilon_max
        step = 0
        while episode < max_episode:
            # update epsilon
            if step > self.epsilon_delay:
                epsilon = max(self.epsilon_min, epsilon-self.epsilon_step)
            # select epsilon-greedy action
            if np.random.rand() < epsilon:
                action = env.action_space.sample()
            else:
                action = greedy_action(self.model, state)
            # step
            next_state, reward, done, trunc, _ = env.step(action)
            self.memory.append(state, action, reward, next_state, done)
            episode_cum_reward += reward
            # train
            for _ in range(self.nb_gradient_steps): 
                self.gradient_step()
            # update target network if needed
            if self.update_target_strategy == 'replace':
                if step % self.update_target_freq == 0: 
                    self.target_model.load_state_dict(self.model.state_dict())
            if self.update_target_strategy == 'ema':
                target_state_dict = self.target_model.state_dict()
                model_state_dict = self.model.state_dict()
                tau = self.update_target_tau
                for key in model_state_dict:
                    target_state_dict[key] = tau*model_state_dict + (1-tau)*target_state_dict
                target_model.load_state_dict(target_state_dict)
            # next transition
            step += 1
            if done or trunc:
                episode += 1
                print("Episode ", '{:3d}'.format(episode), 
                      ", epsilon ", '{:6.2f}'.format(epsilon), 
                      ", batch size ", '{:5d}'.format(len(self.memory)), 
                      ", episode return ", '{:4.1f}'.format(episode_cum_reward),
                      sep='')
                state, _ = env.reset()
                episode_return.append(episode_cum_reward)
                episode_cum_reward = 0
            else:
                state = next_state
        return episode_return

# %%
import gymnasium as gym
cartpole = gym.make('CartPole-v1', render_mode="rgb_array")
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Declare network
state_dim = cartpole.observation_space.shape[0]
n_action = cartpole.action_space.n 
nb_neurons=24
DQN = torch.nn.Sequential(nn.Linear(state_dim, nb_neurons),
                          nn.ReLU(),
                          nn.Linear(nb_neurons, nb_neurons),
                          nn.ReLU(), 
                          nn.Linear(nb_neurons, n_action)).to(device)

# DQN config
config = {'observation_space': cartpole.observation_space.shape[0],
          'nb_actions': cartpole.action_space.n,
          'learning_rate': 0.001,
          'gamma': 0.95,
          'buffer_size': 1000000,
          'epsilon_min': 0.01,
          'epsilon_max': 1.,
          'epsilon_decay_period': 1000,
          'epsilon_delay_decay': 20,
          'batch_size': 20,
          'gradient_steps': 1,
          'update_target_strategy': 'replace', # or 'ema'
          'update_target_freq': 50,
          'update_target_tau': 0.005,
          'criterion': torch.nn.SmoothL1Loss()}

# Train agent
agent = dqn_agent(config, DQN)
scores = agent.train(cartpole, 200)
plt.plot(scores);
# Out:
# Episode   1, epsilon   0.99, batch size    28, episode return 28.0
# Episode   2, epsilon   0.97, batch size    56, episode return 28.0
# Episode   3, epsilon   0.92, batch size    99, episode return 43.0
# Episode   4, epsilon   0.90, batch size   127, episode return 28.0
# Episode   5, epsilon   0.88, batch size   144, episode return 17.0
# Episode   6, epsilon   0.86, batch size   163, episode return 19.0
# Episode   7, epsilon   0.85, batch size   175, episode return 12.0
# Episode   8, epsilon   0.83, batch size   190, episode return 15.0
# Episode   9, epsilon   0.80, batch size   218, episode return 28.0
# Episode  10, epsilon   0.80, batch size   227, episode return  9.0
# Episode  11, epsilon   0.77, batch size   249, episode return 22.0
# Episode  12, epsilon   0.76, batch size   259, episode return 10.0
# Episode  13, epsilon   0.75, batch size   270, episode return 11.0
# Episode  14, epsilon   0.74, batch size   285, episode return 15.0
# Episode  15, epsilon   0.73, batch size   296, episode return 11.0
# Episode  16, epsilon   0.72, batch size   307, episode return 11.0
# Episode  17, epsilon   0.70, batch size   321, episode return 14.0
# Episode  18, epsilon   0.69, batch size   339, episode return 18.0
# Episode  19, epsilon   0.66, batch size   369, episode return 30.0
# Episode  20, epsilon   0.64, batch size   384, episode return 15.0
# Episode  21, epsilon   0.63, batch size   393, episode return  9.0
# Episode  22, epsilon   0.62, batch size   405, episode return 12.0
# Episode  23, epsilon   0.60, batch size   421, episode return 16.0
# Episode  24, epsilon   0.59, batch size   433, episode return 12.0
# Episode  25, epsilon   0.58, batch size   449, episode return 16.0
# Episode  26, epsilon   0.56, batch size   465, episode return 16.0
# Episode  27, epsilon   0.55, batch size   477, episode return 12.0
# Episode  28, epsilon   0.54, batch size   486, episode return  9.0
# Episode  29, epsilon   0.52, batch size   501, episode return 15.0
# Episode  30, epsilon   0.51, batch size   515, episode return 14.0
# Episode  31, epsilon   0.50, batch size   525, episode return 10.0
# Episode  32, epsilon   0.48, batch size   542, episode return 17.0
# Episode  33, epsilon   0.47, batch size   553, episode return 11.0
# Episode  34, epsilon   0.46, batch size   563, episode return 10.0
# Episode  35, epsilon   0.45, batch size   574, episode return 11.0
# Episode  36, epsilon   0.44, batch size   591, episode return 17.0
# Episode  37, epsilon   0.42, batch size   606, episode return 15.0
# Episode  38, epsilon   0.41, batch size   622, episode return 16.0
# Episode  39, epsilon   0.39, batch size   638, episode return 16.0
# Episode  40, epsilon   0.38, batch size   648, episode return 10.0
# Episode  41, epsilon   0.36, batch size   663, episode return 15.0
# Episode  42, epsilon   0.36, batch size   672, episode return  9.0
# Episode  43, epsilon   0.34, batch size   688, episode return 16.0
# Episode  44, epsilon   0.33, batch size   700, episode return 12.0
# Episode  45, epsilon   0.31, batch size   720, episode return 20.0
# Episode  46, epsilon   0.30, batch size   733, episode return 13.0
# Episode  47, epsilon   0.28, batch size   753, episode return 20.0
# Episode  48, epsilon   0.26, batch size   765, episode return 12.0
# Episode  49, epsilon   0.25, batch size   776, episode return 11.0
# Episode  50, epsilon   0.24, batch size   785, episode return  9.0
# Episode  51, epsilon   0.23, batch size   796, episode return 11.0
# Episode  52, epsilon   0.22, batch size   807, episode return 11.0
# Episode  53, epsilon   0.21, batch size   817, episode return 10.0
# Episode  54, epsilon   0.20, batch size   827, episode return 10.0
# Episode  55, epsilon   0.19, batch size   836, episode return  9.0
# Episode  56, epsilon   0.19, batch size   844, episode return  8.0
# Episode  57, epsilon   0.17, batch size   856, episode return 12.0
# Episode  58, epsilon   0.17, batch size   864, episode return  8.0
# Episode  59, epsilon   0.16, batch size   873, episode return  9.0
# Episode  60, epsilon   0.14, batch size   885, episode return 12.0
# Episode  61, epsilon   0.13, batch size   895, episode return 10.0
# Episode  62, epsilon   0.13, batch size   904, episode return  9.0
# Episode  63, epsilon   0.11, batch size   917, episode return 13.0
# Episode  64, epsilon   0.10, batch size   927, episode return 10.0
# Episode  65, epsilon   0.09, batch size   939, episode return 12.0
# Episode  66, epsilon   0.08, batch size   947, episode return  8.0
# Episode  67, epsilon   0.07, batch size   957, episode return 10.0
# Episode  68, epsilon   0.06, batch size   969, episode return 12.0
# Episode  69, epsilon   0.05, batch size   980, episode return 11.0
# Episode  70, epsilon   0.04, batch size   989, episode return  9.0
# Episode  71, epsilon   0.03, batch size   998, episode return  9.0
# Episode  72, epsilon   0.02, batch size  1006, episode return  8.0
# Episode  73, epsilon   0.02, batch size  1015, episode return  9.0
# Episode  74, epsilon   0.01, batch size  1024, episode return  9.0
# Episode  75, epsilon   0.01, batch size  1033, episode return  9.0
# Episode  76, epsilon   0.01, batch size  1043, episode return 10.0
# Episode  77, epsilon   0.01, batch size  1052, episode return  9.0
# Episode  78, epsilon   0.01, batch size  1061, episode return  9.0
# Episode  79, epsilon   0.01, batch size  1086, episode return 25.0
# Episode  80, epsilon   0.01, batch size  1096, episode return 10.0
# Episode  81, epsilon   0.01, batch size  1106, episode return 10.0
# Episode  82, epsilon   0.01, batch size  1242, episode return 136.0
# Episode  83, epsilon   0.01, batch size  1273, episode return 31.0
# Episode  84, epsilon   0.01, batch size  1298, episode return 25.0
# Episode  85, epsilon   0.01, batch size  1321, episode return 23.0
# Episode  86, epsilon   0.01, batch size  1349, episode return 28.0
# Episode  87, epsilon   0.01, batch size  1372, episode return 23.0
# Episode  88, epsilon   0.01, batch size  1394, episode return 22.0
# Episode  89, epsilon   0.01, batch size  1420, episode return 26.0
# Episode  90, epsilon   0.01, batch size  1442, episode return 22.0
# Episode  91, epsilon   0.01, batch size  1461, episode return 19.0
# Episode  92, epsilon   0.01, batch size  1482, episode return 21.0
# Episode  93, epsilon   0.01, batch size  1499, episode return 17.0
# Episode  94, epsilon   0.01, batch size  1515, episode return 16.0
# Episode  95, epsilon   0.01, batch size  1534, episode return 19.0
# Episode  96, epsilon   0.01, batch size  1551, episode return 17.0
# Episode  97, epsilon   0.01, batch size  1568, episode return 17.0
# Episode  98, epsilon   0.01, batch size  1594, episode return 26.0
# Episode  99, epsilon   0.01, batch size  1620, episode return 26.0
# Episode 100, epsilon   0.01, batch size  1649, episode return 29.0
# Episode 101, epsilon   0.01, batch size  1672, episode return 23.0
# Episode 102, epsilon   0.01, batch size  1696, episode return 24.0
# Episode 103, epsilon   0.01, batch size  1718, episode return 22.0
# Episode 104, epsilon   0.01, batch size  1760, episode return 42.0
# Episode 105, epsilon   0.01, batch size  1802, episode return 42.0
# Episode 106, epsilon   0.01, batch size  1851, episode return 49.0
# Episode 107, epsilon   0.01, batch size  1880, episode return 29.0
# Episode 108, epsilon   0.01, batch size  1915, episode return 35.0
# Episode 109, epsilon   0.01, batch size  1945, episode return 30.0
# Episode 110, epsilon   0.01, batch size  1985, episode return 40.0
# Episode 111, epsilon   0.01, batch size  2020, episode return 35.0
# Episode 112, epsilon   0.01, batch size  2052, episode return 32.0
# Episode 113, epsilon   0.01, batch size  2097, episode return 45.0
# Episode 114, epsilon   0.01, batch size  2135, episode return 38.0
# Episode 115, epsilon   0.01, batch size  2167, episode return 32.0
# Episode 116, epsilon   0.01, batch size  2197, episode return 30.0
# Episode 117, epsilon   0.01, batch size  2226, episode return 29.0
# Episode 118, epsilon   0.01, batch size  2272, episode return 46.0
# Episode 119, epsilon   0.01, batch size  2286, episode return 14.0
# Episode 120, epsilon   0.01, batch size  2327, episode return 41.0
# Episode 121, epsilon   0.01, batch size  2356, episode return 29.0
# Episode 122, epsilon   0.01, batch size  2397, episode return 41.0
# Episode 123, epsilon   0.01, batch size  2450, episode return 53.0
# Episode 124, epsilon   0.01, batch size  2657, episode return 207.0
# Episode 125, epsilon   0.01, batch size  2667, episode return 10.0
# Episode 126, epsilon   0.01, batch size  2678, episode return 11.0
# Episode 127, epsilon   0.01, batch size  2717, episode return 39.0
# Episode 128, epsilon   0.01, batch size  2733, episode return 16.0
# Episode 129, epsilon   0.01, batch size  2776, episode return 43.0
# Episode 130, epsilon   0.01, batch size  2814, episode return 38.0
# Episode 131, epsilon   0.01, batch size  2869, episode return 55.0
# Episode 132, epsilon   0.01, batch size  2923, episode return 54.0
# Episode 133, epsilon   0.01, batch size  2962, episode return 39.0
# Episode 134, epsilon   0.01, batch size  3000, episode return 38.0
# Episode 135, epsilon   0.01, batch size  3033, episode return 33.0
# Episode 136, epsilon   0.01, batch size  3064, episode return 31.0
# Episode 137, epsilon   0.01, batch size  3133, episode return 69.0
# Episode 138, epsilon   0.01, batch size  3172, episode return 39.0
# Episode 139, epsilon   0.01, batch size  3300, episode return 128.0
# Episode 140, epsilon   0.01, batch size  3351, episode return 51.0
# Episode 141, epsilon   0.01, batch size  3378, episode return 27.0
# Episode 142, epsilon   0.01, batch size  3478, episode return 100.0
# Episode 143, epsilon   0.01, batch size  3584, episode return 106.0
# Episode 144, epsilon   0.01, batch size  3733, episode return 149.0
# Episode 145, epsilon   0.01, batch size  3868, episode return 135.0
# Episode 146, epsilon   0.01, batch size  4057, episode return 189.0
# Episode 147, epsilon   0.01, batch size  4091, episode return 34.0
# Episode 148, epsilon   0.01, batch size  4234, episode return 143.0
# Episode 149, epsilon   0.01, batch size  4285, episode return 51.0
# Episode 150, epsilon   0.01, batch size  4358, episode return 73.0
# Episode 151, epsilon   0.01, batch size  4527, episode return 169.0
# Episode 152, epsilon   0.01, batch size  4665, episode return 138.0
# Episode 153, epsilon   0.01, batch size  4769, episode return 104.0
# Episode 154, epsilon   0.01, batch size  4969, episode return 200.0
# Episode 155, epsilon   0.01, batch size  5075, episode return 106.0
# Episode 156, epsilon   0.01, batch size  5215, episode return 140.0
# Episode 157, epsilon   0.01, batch size  5337, episode return 122.0
# Episode 158, epsilon   0.01, batch size  5581, episode return 244.0
# Episode 159, epsilon   0.01, batch size  5839, episode return 258.0
# Episode 160, epsilon   0.01, batch size  6325, episode return 486.0
# Episode 161, epsilon   0.01, batch size  6547, episode return 222.0
# Episode 162, epsilon   0.01, batch size  6753, episode return 206.0
# Episode 163, epsilon   0.01, batch size  6969, episode return 216.0
# Episode 164, epsilon   0.01, batch size  7200, episode return 231.0
# Episode 165, epsilon   0.01, batch size  7464, episode return 264.0
# Episode 166, epsilon   0.01, batch size  7759, episode return 295.0
# Episode 167, epsilon   0.01, batch size  7932, episode return 173.0
# Episode 168, epsilon   0.01, batch size  8326, episode return 394.0
# Episode 169, epsilon   0.01, batch size  8534, episode return 208.0
# Episode 170, epsilon   0.01, batch size  8732, episode return 198.0
# Episode 171, epsilon   0.01, batch size  8879, episode return 147.0
# Episode 172, epsilon   0.01, batch size  9072, episode return 193.0
# Episode 173, epsilon   0.01, batch size  9314, episode return 242.0
# Episode 174, epsilon   0.01, batch size  9508, episode return 194.0
# Episode 175, epsilon   0.01, batch size  9671, episode return 163.0
# Episode 176, epsilon   0.01, batch size  9859, episode return 188.0
# Episode 177, epsilon   0.01, batch size 10132, episode return 273.0
# Episode 178, epsilon   0.01, batch size 10489, episode return 357.0
# Episode 179, epsilon   0.01, batch size 10768, episode return 279.0
# Episode 180, epsilon   0.01, batch size 11087, episode return 319.0
# Episode 181, epsilon   0.01, batch size 11276, episode return 189.0
# Episode 182, epsilon   0.01, batch size 11537, episode return 261.0
# Episode 183, epsilon   0.01, batch size 12037, episode return 500.0
# Episode 184, epsilon   0.01, batch size 12268, episode return 231.0
# Episode 185, epsilon   0.01, batch size 12534, episode return 266.0
# Episode 186, epsilon   0.01, batch size 12809, episode return 275.0
# Episode 187, epsilon   0.01, batch size 13019, episode return 210.0
# Episode 188, epsilon   0.01, batch size 13446, episode return 427.0
# Episode 189, epsilon   0.01, batch size 13748, episode return 302.0
# Episode 190, epsilon   0.01, batch size 13962, episode return 214.0
# Episode 191, epsilon   0.01, batch size 14180, episode return 218.0
# Episode 192, epsilon   0.01, batch size 14451, episode return 271.0
# Episode 193, epsilon   0.01, batch size 14747, episode return 296.0
# Episode 194, epsilon   0.01, batch size 14954, episode return 207.0
# Episode 195, epsilon   0.01, batch size 15383, episode return 429.0
# Episode 196, epsilon   0.01, batch size 15581, episode return 198.0
# Episode 197, epsilon   0.01, batch size 15791, episode return 210.0
# Episode 198, epsilon   0.01, batch size 16029, episode return 238.0
# Episode 199, epsilon   0.01, batch size 16271, episode return 242.0
# Episode 200, epsilon   0.01, batch size 16599, episode return 328.0

# %%
import gymnasium as gym
from solutions.dqn_greedy_action import greedy_action

cartpole = gym.make('CartPole-v1', render_mode="human")
s,_ = cartpole.reset()
for t in range(1000):
    a = greedy_action(DQN,s)
    s2,r,d,trunc,_ = cartpole.step(a)
    cartpole.render()
    s = s2
    if d:
        break

cartpole.close()

# %% [markdown]
# ## Monitoring progress
#
# In the previous experiments, we have counted the number of steps per training episode. But during these episodes, the applied policy was $\epsilon$-greedy, not greedy. So this is not an objective measure of performance. Let's try to correct this.
#
# <div class="alert alert-warning">
#
# **Exercise:**
# Enhance your previous code with the monitoring, after each episode, of:
# - the number of steps of the training episode
# - a Monte Carlo estimate of the total sum of rewards from the (distribution of) starting state,
# - a Monte Carlo estimate of the sum of discounted rewards from the (distribution of) starting state,
# - an average, over possible starting states $s_0$ of the current $\max_a Q(s_0,a)$.
# </div>

# %%
# %load solutions/dqn_agent.py
import numpy as np
import torch
import torch.nn as nn
from copy import deepcopy
from solutions.replay_buffer2 import ReplayBuffer
from solutions.dqn_greedy_action import greedy_action

class dqn_agent:
    def __init__(self, config, model):
        device = "cuda" if next(model.parameters()).is_cuda else "cpu"
        self.nb_actions = config['nb_actions']
        self.gamma = config['gamma'] if 'gamma' in config.keys() else 0.95
        self.batch_size = config['batch_size'] if 'batch_size' in config.keys() else 100
        buffer_size = config['buffer_size'] if 'buffer_size' in config.keys() else int(1e5)
        self.memory = ReplayBuffer(buffer_size,device)
        self.epsilon_max = config['epsilon_max'] if 'epsilon_max' in config.keys() else 1.
        self.epsilon_min = config['epsilon_min'] if 'epsilon_min' in config.keys() else 0.01
        self.epsilon_stop = config['epsilon_decay_period'] if 'epsilon_decay_period' in config.keys() else 1000
        self.epsilon_delay = config['epsilon_delay_decay'] if 'epsilon_delay_decay' in config.keys() else 20
        self.epsilon_step = (self.epsilon_max-self.epsilon_min)/self.epsilon_stop
        self.model = model 
        self.target_model = deepcopy(self.model).to(device)
        self.criterion = config['criterion'] if 'criterion' in config.keys() else torch.nn.MSELoss()
        lr = config['learning_rate'] if 'learning_rate' in config.keys() else 0.001
        self.optimizer = config['optimizer'] if 'optimizer' in config.keys() else torch.optim.Adam(self.model.parameters(), lr=lr)
        self.nb_gradient_steps = config['gradient_steps'] if 'gradient_steps' in config.keys() else 1
        self.update_target_strategy = config['update_target_strategy'] if 'update_target_strategy' in config.keys() else 'replace'
        self.update_target_freq = config['update_target_freq'] if 'update_target_freq' in config.keys() else 20
        self.update_target_tau = config['update_target_tau'] if 'update_target_tau' in config.keys() else 0.005
        self.monitoring_nb_trials = config['monitoring_nb_trials'] if 'monitoring_nb_trials' in config.keys() else 0

    def MC_eval(self, env, nb_trials):   # NEW NEW NEW
        MC_total_reward = []
        MC_discounted_reward = []
        for _ in range(nb_trials):
            x,_ = env.reset()
            done = False
            trunc = False
            total_reward = 0
            discounted_reward = 0
            step = 0
            while not (done or trunc):
                a = greedy_action(self.model, x)
                y,r,done,trunc,_ = env.step(a)
                x = y
                total_reward += r
                discounted_reward += self.gamma**step * r
                step += 1
            MC_total_reward.append(total_reward)
            MC_discounted_reward.append(discounted_reward)
        return np.mean(MC_discounted_reward), np.mean(MC_total_reward)
    
    def V_initial_state(self, env, nb_trials):   # NEW NEW NEW
        with torch.no_grad():
            for _ in range(nb_trials):
                val = []
                x,_ = env.reset()
                val.append(self.model(torch.Tensor(x).unsqueeze(0).to(device)).max().item())
        return np.mean(val)
    
    def gradient_step(self):
        if len(self.memory) > self.batch_size:
            X, A, R, Y, D = self.memory.sample(self.batch_size)
            QYmax = self.target_model(Y).max(1)[0].detach()
            update = torch.addcmul(R, self.gamma, 1-D, QYmax)
            QXA = self.model(X).gather(1, A.to(torch.long).unsqueeze(1))
            loss = self.criterion(QXA, update.unsqueeze(1))
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step() 
    
    def train(self, env, max_episode):
        episode_return = []
        MC_avg_total_reward = []   # NEW NEW NEW
        MC_avg_discounted_reward = []   # NEW NEW NEW
        V_init_state = []   # NEW NEW NEW
        episode = 0
        episode_cum_reward = 0
        state, _ = env.reset()
        epsilon = self.epsilon_max
        step = 0
        while episode < max_episode:
            # update epsilon
            if step > self.epsilon_delay:
                epsilon = max(self.epsilon_min, epsilon-self.epsilon_step)
            # select epsilon-greedy action
            if np.random.rand() < epsilon:
                action = env.action_space.sample()
            else:
                action = greedy_action(self.model, state)
            # step
            next_state, reward, done, trunc, _ = env.step(action)
            self.memory.append(state, action, reward, next_state, done)
            episode_cum_reward += reward
            # train
            for _ in range(self.nb_gradient_steps): 
                self.gradient_step()
            # update target network if needed
            if self.update_target_strategy == 'replace':
                if step % self.update_target_freq == 0: 
                    self.target_model.load_state_dict(self.model.state_dict())
            if self.update_target_strategy == 'ema':
                target_state_dict = self.target_model.state_dict()
                model_state_dict = self.model.state_dict()
                tau = self.update_target_tau
                for key in model_state_dict:
                    target_state_dict[key] = tau*model_state_dict + (1-tau)*target_state_dict
                target_model.load_state_dict(target_state_dict)
            # next transition
            step += 1
            if done or trunc:
                episode += 1
                # Monitoring
                if self.monitoring_nb_trials>0:
                    MC_dr, MC_tr = self.MC_eval(env, self.monitoring_nb_trials)    # NEW NEW NEW
                    V0 = self.V_initial_state(env, self.monitoring_nb_trials)   # NEW NEW NEW
                    MC_avg_total_reward.append(MC_tr)   # NEW NEW NEW
                    MC_avg_discounted_reward.append(MC_dr)   # NEW NEW NEW
                    V_init_state.append(V0)   # NEW NEW NEW
                    episode_return.append(episode_cum_reward)   # NEW NEW NEW
                    print("Episode ", '{:2d}'.format(episode), 
                          ", epsilon ", '{:6.2f}'.format(epsilon), 
                          ", batch size ", '{:4d}'.format(len(self.memory)), 
                          ", ep return ", '{:4.1f}'.format(episode_cum_reward), 
                          ", MC tot ", '{:6.2f}'.format(MC_tr),
                          ", MC disc ", '{:6.2f}'.format(MC_dr),
                          ", V0 ", '{:6.2f}'.format(V0),
                          sep='')
                else:
                    episode_return.append(episode_cum_reward)
                    print("Episode ", '{:2d}'.format(episode), 
                          ", epsilon ", '{:6.2f}'.format(epsilon), 
                          ", batch size ", '{:4d}'.format(len(self.memory)), 
                          ", ep return ", '{:4.1f}'.format(episode_cum_reward), 
                          sep='')

                
                state, _ = env.reset()
                episode_cum_reward = 0
            else:
                state = next_state
        return episode_return, MC_avg_discounted_reward, MC_avg_total_reward, V_init_state

# %%
import gymnasium as gym
cartpole = gym.make('CartPole-v1', render_mode="rgb_array")
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Declare network
state_dim = cartpole.observation_space.shape[0]
n_action = cartpole.action_space.n 
nb_neurons=24
DQN = torch.nn.Sequential(nn.Linear(state_dim, nb_neurons),
                          nn.ReLU(),
                          nn.Linear(nb_neurons, nb_neurons),
                          nn.ReLU(), 
                          nn.Linear(nb_neurons, n_action)).to(device)

# DQN config
config = {'observation_space': cartpole.observation_space.shape[0],
          'nb_actions': cartpole.action_space.n,
          'learning_rate': 0.001,
          'gamma': 0.95,
          'buffer_size': 1000000,
          'epsilon_min': 0.01,
          'epsilon_max': 1.,
          'epsilon_decay_period': 1000,
          'epsilon_delay_decay': 20,
          'batch_size': 20,
          'gradient_steps': 1,
          'update_target_strategy': 'replace', # or 'ema'
          'update_target_freq': 50,
          'update_target_tau': 0.005,
          'criterion': torch.nn.SmoothL1Loss(),
          'monitoring_nb_trials': 50}

# Train agent
agent = dqn_agent(config, DQN)
ep_length, disc_rewards, tot_rewards, V0 = agent.train(cartpole, 200)
plt.plot(ep_length, label="training episode length")
plt.plot(tot_rewards, label="MC eval of total reward")
plt.legend()
plt.figure()
plt.plot(disc_rewards, label="MC eval of discounted reward")
plt.plot(V0, label="average $max_a Q(s_0)$")
plt.legend();
# Out:
# Episode  1, epsilon   1.00, batch size   14, ep return 14.0, MC tot   9.54, MC disc   7.73, V0  -0.00
# Episode  2, epsilon   0.97, batch size   49, ep return 35.0, MC tot  16.64, MC disc  11.40, V0   0.17
# Episode  3, epsilon   0.95, batch size   70, ep return 21.0, MC tot  81.18, MC disc  19.00, V0   0.30
# Episode  4, epsilon   0.94, batch size   79, ep return  9.0, MC tot  53.72, MC disc  17.41, V0   0.39
# Episode  5, epsilon   0.93, batch size   96, ep return 17.0, MC tot  20.98, MC disc  13.05, V0   0.57
# Episode  6, epsilon   0.89, batch size  137, ep return 41.0, MC tot   9.32, MC disc   7.59, V0   1.26
# Episode  7, epsilon   0.88, batch size  146, ep return  9.0, MC tot   9.24, MC disc   7.54, V0   1.40
# Episode  8, epsilon   0.85, batch size  176, ep return 30.0, MC tot   9.28, MC disc   7.57, V0   2.15
# Episode  9, epsilon   0.83, batch size  188, ep return 12.0, MC tot   9.34, MC disc   7.60, V0   2.23
# Episode 10, epsilon   0.82, batch size  201, ep return 13.0, MC tot   9.38, MC disc   7.63, V0   2.22
# Episode 11, epsilon   0.80, batch size  220, ep return 19.0, MC tot   9.22, MC disc   7.52, V0   2.90
# Episode 12, epsilon   0.79, batch size  233, ep return 13.0, MC tot   9.20, MC disc   7.51, V0   3.29
# Episode 13, epsilon   0.78, batch size  242, ep return  9.0, MC tot   9.12, MC disc   7.46, V0   3.19
# Episode 14, epsilon   0.77, batch size  254, ep return 12.0, MC tot   9.30, MC disc   7.58, V0   3.22
# Episode 15, epsilon   0.76, batch size  267, ep return 13.0, MC tot   9.52, MC disc   7.72, V0   3.84
# Episode 16, epsilon   0.74, batch size  288, ep return 21.0, MC tot   9.26, MC disc   7.55, V0   4.21
# Episode 17, epsilon   0.72, batch size  300, ep return 12.0, MC tot   9.50, MC disc   7.71, V0   4.06
# Episode 18, epsilon   0.71, batch size  317, ep return 17.0, MC tot   9.28, MC disc   7.56, V0   4.93
# Episode 19, epsilon   0.68, batch size  341, ep return 24.0, MC tot   9.24, MC disc   7.54, V0   5.04
# Episode 20, epsilon   0.66, batch size  363, ep return 22.0, MC tot   9.08, MC disc   7.44, V0   5.76
# Episode 21, epsilon   0.65, batch size  375, ep return 12.0, MC tot   9.34, MC disc   7.61, V0   6.02
# Episode 22, epsilon   0.63, batch size  392, ep return 17.0, MC tot   9.26, MC disc   7.56, V0   5.70
# Episode 23, epsilon   0.62, batch size  403, ep return 11.0, MC tot   9.24, MC disc   7.54, V0   5.77
# Episode 24, epsilon   0.61, batch size  412, ep return  9.0, MC tot   9.30, MC disc   7.58, V0   6.55
# Episode 25, epsilon   0.60, batch size  423, ep return 11.0, MC tot   9.32, MC disc   7.59, V0   6.79
# Episode 26, epsilon   0.59, batch size  438, ep return 15.0, MC tot   9.40, MC disc   7.64, V0   6.58
# Episode 27, epsilon   0.58, batch size  450, ep return 12.0, MC tot   9.60, MC disc   7.77, V0   6.64
# Episode 28, epsilon   0.56, batch size  462, ep return 12.0, MC tot   9.40, MC disc   7.64, V0   7.69
# Episode 29, epsilon   0.55, batch size  478, ep return 16.0, MC tot   9.34, MC disc   7.60, V0   7.26
# Episode 30, epsilon   0.54, batch size  487, ep return  9.0, MC tot   9.44, MC disc   7.67, V0   7.50
# Episode 31, epsilon   0.52, batch size  503, ep return 16.0, MC tot   9.26, MC disc   7.55, V0   7.88
# Episode 32, epsilon   0.51, batch size  511, ep return  8.0, MC tot   9.28, MC disc   7.56, V0   8.14
# Episode 33, epsilon   0.50, batch size  524, ep return 13.0, MC tot   9.26, MC disc   7.55, V0   8.35
# Episode 34, epsilon   0.49, batch size  535, ep return 11.0, MC tot   9.16, MC disc   7.49, V0   8.14
# Episode 35, epsilon   0.48, batch size  544, ep return  9.0, MC tot   9.52, MC disc   7.72, V0   8.54
# Episode 36, epsilon   0.47, batch size  558, ep return 14.0, MC tot   9.36, MC disc   7.62, V0   8.76
# Episode 37, epsilon   0.46, batch size  569, ep return 11.0, MC tot   9.34, MC disc   7.61, V0   9.30
# Episode 38, epsilon   0.45, batch size  579, ep return 10.0, MC tot   9.26, MC disc   7.56, V0   9.39
# Episode 39, epsilon   0.44, batch size  589, ep return 10.0, MC tot   9.38, MC disc   7.63, V0   9.13
# Episode 40, epsilon   0.42, batch size  611, ep return 22.0, MC tot   9.24, MC disc   7.54, V0  10.14
# Episode 41, epsilon   0.40, batch size  623, ep return 12.0, MC tot   9.40, MC disc   7.64, V0  10.35
# Episode 42, epsilon   0.39, batch size  633, ep return 10.0, MC tot   9.26, MC disc   7.55, V0  10.31
# Episode 43, epsilon   0.38, batch size  643, ep return 10.0, MC tot   9.28, MC disc   7.57, V0  10.16
# Episode 44, epsilon   0.37, batch size  658, ep return 15.0, MC tot   9.46, MC disc   7.68, V0  10.68
# Episode 45, epsilon   0.36, batch size  670, ep return 12.0, MC tot   9.36, MC disc   7.61, V0  11.25
# Episode 46, epsilon   0.34, batch size  683, ep return 13.0, MC tot   9.56, MC disc   7.75, V0  10.89
# Episode 47, epsilon   0.33, batch size  695, ep return 12.0, MC tot   9.22, MC disc   7.53, V0  11.14
# Episode 48, epsilon   0.32, batch size  704, ep return  9.0, MC tot   9.22, MC disc   7.53, V0  11.22
# Episode 49, epsilon   0.31, batch size  716, ep return 12.0, MC tot   9.44, MC disc   7.67, V0  11.88
# Episode 50, epsilon   0.30, batch size  728, ep return 12.0, MC tot   9.34, MC disc   7.61, V0  11.63
# Episode 51, epsilon   0.28, batch size  747, ep return 19.0, MC tot   9.18, MC disc   7.50, V0  11.89
# Episode 52, epsilon   0.27, batch size  758, ep return 11.0, MC tot   9.20, MC disc   7.52, V0  12.03
# Episode 53, epsilon   0.26, batch size  769, ep return 11.0, MC tot   9.28, MC disc   7.56, V0  12.36
# Episode 54, epsilon   0.25, batch size  778, ep return  9.0, MC tot   9.44, MC disc   7.67, V0  12.48
# Episode 55, epsilon   0.24, batch size  787, ep return  9.0, MC tot   9.16, MC disc   7.49, V0  12.40
# Episode 56, epsilon   0.23, batch size  796, ep return  9.0, MC tot   9.42, MC disc   7.65, V0  12.66
# Episode 57, epsilon   0.22, batch size  805, ep return  9.0, MC tot   9.34, MC disc   7.60, V0  12.37
# Episode 58, epsilon   0.21, batch size  815, ep return 10.0, MC tot   9.42, MC disc   7.65, V0  12.99
# Episode 59, epsilon   0.20, batch size  826, ep return 11.0, MC tot   9.84, MC disc   7.91, V0  12.76
# Episode 60, epsilon   0.19, batch size  835, ep return  9.0, MC tot   9.46, MC disc   7.68, V0  13.42
# Episode 61, epsilon   0.19, batch size  844, ep return  9.0, MC tot   9.42, MC disc   7.66, V0  13.29
# Episode 62, epsilon   0.17, batch size  855, ep return 11.0, MC tot   9.60, MC disc   7.76, V0  13.14
# Episode 63, epsilon   0.16, batch size  867, ep return 12.0, MC tot  11.04, MC disc   8.62, V0  13.91
# Episode 64, epsilon   0.15, batch size  881, ep return 14.0, MC tot  10.60, MC disc   8.37, V0  13.41
# Episode 65, epsilon   0.14, batch size  891, ep return 10.0, MC tot  10.12, MC disc   8.08, V0  13.83
# Episode 66, epsilon   0.13, batch size  901, ep return 10.0, MC tot  10.26, MC disc   8.17, V0  13.77
# Episode 67, epsilon   0.12, batch size  910, ep return  9.0, MC tot  10.54, MC disc   8.34, V0  13.81
# Episode 68, epsilon   0.10, batch size  931, ep return 21.0, MC tot  13.20, MC disc   9.81, V0  14.55
# Episode 69, epsilon   0.08, batch size  946, ep return 15.0, MC tot  11.18, MC disc   8.70, V0  14.36
# Episode 70, epsilon   0.07, batch size  958, ep return 12.0, MC tot  13.22, MC disc   9.81, V0  13.98
# Episode 71, epsilon   0.06, batch size  970, ep return 12.0, MC tot  16.08, MC disc  11.15, V0  14.46
# Episode 72, epsilon   0.05, batch size  985, ep return 15.0, MC tot  16.54, MC disc  11.37, V0  14.08
# Episode 73, epsilon   0.03, batch size  999, ep return 14.0, MC tot  14.46, MC disc  10.42, V0  14.69
# Episode 74, epsilon   0.02, batch size 1012, ep return 13.0, MC tot  14.60, MC disc  10.50, V0  14.81
# Episode 75, epsilon   0.01, batch size 1027, ep return 15.0, MC tot  15.80, MC disc  11.05, V0  14.75
# Episode 76, epsilon   0.01, batch size 1040, ep return 13.0, MC tot  17.68, MC disc  11.87, V0  15.24
# Episode 77, epsilon   0.01, batch size 1056, ep return 16.0, MC tot  17.76, MC disc  11.90, V0  14.41
# Episode 78, epsilon   0.01, batch size 1072, ep return 16.0, MC tot  18.08, MC disc  12.03, V0  14.89
# Episode 79, epsilon   0.01, batch size 1096, ep return 24.0, MC tot  17.46, MC disc  11.76, V0  15.05
# Episode 80, epsilon   0.01, batch size 1111, ep return 15.0, MC tot  16.34, MC disc  11.28, V0  15.10
# Episode 81, epsilon   0.01, batch size 1130, ep return 19.0, MC tot  22.02, MC disc  13.42, V0  15.82
# Episode 82, epsilon   0.01, batch size 1182, ep return 52.0, MC tot  26.96, MC disc  13.94, V0  15.82
# Episode 83, epsilon   0.01, batch size 1224, ep return 42.0, MC tot   9.46, MC disc   7.68, V0  15.40
# Episode 84, epsilon   0.01, batch size 1234, ep return 10.0, MC tot   9.18, MC disc   7.50, V0  15.69
# Episode 85, epsilon   0.01, batch size 1244, ep return 10.0, MC tot  20.42, MC disc  12.46, V0  15.74
# Episode 86, epsilon   0.01, batch size 1261, ep return 17.0, MC tot   9.60, MC disc   7.77, V0  16.61
# Episode 87, epsilon   0.01, batch size 1271, ep return 10.0, MC tot   9.36, MC disc   7.61, V0  16.30
# Episode 88, epsilon   0.01, batch size 1279, ep return  8.0, MC tot   9.54, MC disc   7.73, V0  15.73
# Episode 89, epsilon   0.01, batch size 1288, ep return  9.0, MC tot  21.24, MC disc  12.28, V0  16.22
# Episode 90, epsilon   0.01, batch size 1302, ep return 14.0, MC tot   9.22, MC disc   7.53, V0  16.05
# Episode 91, epsilon   0.01, batch size 1311, ep return  9.0, MC tot   9.44, MC disc   7.67, V0  17.19
# Episode 92, epsilon   0.01, batch size 1321, ep return 10.0, MC tot   9.36, MC disc   7.62, V0  16.84
# Episode 93, epsilon   0.01, batch size 1330, ep return  9.0, MC tot   9.38, MC disc   7.63, V0  16.78
# Episode 94, epsilon   0.01, batch size 1340, ep return 10.0, MC tot   9.40, MC disc   7.64, V0  16.51
# Episode 95, epsilon   0.01, batch size 1350, ep return 10.0, MC tot   9.34, MC disc   7.60, V0  16.29
# Episode 96, epsilon   0.01, batch size 1360, ep return 10.0, MC tot   9.50, MC disc   7.70, V0  16.96
# Episode 97, epsilon   0.01, batch size 1370, ep return 10.0, MC tot   9.44, MC disc   7.67, V0  16.60
# Episode 98, epsilon   0.01, batch size 1379, ep return  9.0, MC tot   9.30, MC disc   7.58, V0  16.97
# Episode 99, epsilon   0.01, batch size 1388, ep return  9.0, MC tot   9.46, MC disc   7.68, V0  16.46
# Episode 100, epsilon   0.01, batch size 1397, ep return  9.0, MC tot   9.36, MC disc   7.62, V0  17.42
# Episode 101, epsilon   0.01, batch size 1407, ep return 10.0, MC tot   9.24, MC disc   7.54, V0  17.55
# Episode 102, epsilon   0.01, batch size 1417, ep return 10.0, MC tot   9.26, MC disc   7.55, V0  17.41
# Episode 103, epsilon   0.01, batch size 1426, ep return  9.0, MC tot   9.34, MC disc   7.61, V0  17.69
# Episode 104, epsilon   0.01, batch size 1436, ep return 10.0, MC tot   9.50, MC disc   7.71, V0  17.84
# Episode 105, epsilon   0.01, batch size 1446, ep return 10.0, MC tot   9.30, MC disc   7.58, V0  17.23
# Episode 106, epsilon   0.01, batch size 1456, ep return 10.0, MC tot   9.40, MC disc   7.64, V0  18.33
# Episode 107, epsilon   0.01, batch size 1466, ep return 10.0, MC tot   9.58, MC disc   7.76, V0  18.51
# Episode 108, epsilon   0.01, batch size 1475, ep return  9.0, MC tot   9.46, MC disc   7.68, V0  18.37
# Episode 109, epsilon   0.01, batch size 1485, ep return 10.0, MC tot   9.40, MC disc   7.64, V0  18.43
# Episode 110, epsilon   0.01, batch size 1494, ep return  9.0, MC tot   9.52, MC disc   7.71, V0  18.56
# Episode 111, epsilon   0.01, batch size 1503, ep return  9.0, MC tot   9.40, MC disc   7.64, V0  18.91
# Episode 112, epsilon   0.01, batch size 1513, ep return 10.0, MC tot   9.26, MC disc   7.55, V0  19.07
# Episode 113, epsilon   0.01, batch size 1523, ep return 10.0, MC tot   9.30, MC disc   7.58, V0  18.29
# Episode 114, epsilon   0.01, batch size 1533, ep return 10.0, MC tot   9.32, MC disc   7.59, V0  18.33
# Episode 115, epsilon   0.01, batch size 1542, ep return  9.0, MC tot   9.28, MC disc   7.56, V0  19.31
# Episode 116, epsilon   0.01, batch size 1552, ep return 10.0, MC tot   9.32, MC disc   7.59, V0  19.04
# Episode 117, epsilon   0.01, batch size 1562, ep return 10.0, MC tot   9.36, MC disc   7.61, V0  19.11
# Episode 118, epsilon   0.01, batch size 1571, ep return  9.0, MC tot   9.30, MC disc   7.58, V0  19.20
# Episode 119, epsilon   0.01, batch size 1582, ep return 11.0, MC tot   9.18, MC disc   7.50, V0  19.04
# Episode 120, epsilon   0.01, batch size 1591, ep return  9.0, MC tot   9.46, MC disc   7.68, V0  19.73
# Episode 121, epsilon   0.01, batch size 1599, ep return  8.0, MC tot   9.10, MC disc   7.45, V0  19.11
# Episode 122, epsilon   0.01, batch size 1608, ep return  9.0, MC tot   9.24, MC disc   7.54, V0  20.09
# Episode 123, epsilon   0.01, batch size 1617, ep return  9.0, MC tot   9.24, MC disc   7.54, V0  19.81
# Episode 124, epsilon   0.01, batch size 1627, ep return 10.0, MC tot   9.40, MC disc   7.64, V0  19.02
# Episode 125, epsilon   0.01, batch size 1637, ep return 10.0, MC tot   9.16, MC disc   7.49, V0  19.03
# Episode 126, epsilon   0.01, batch size 1647, ep return 10.0, MC tot   9.28, MC disc   7.57, V0  20.45
# Episode 127, epsilon   0.01, batch size 1655, ep return  8.0, MC tot   9.54, MC disc   7.73, V0  19.67
# Episode 128, epsilon   0.01, batch size 1664, ep return  9.0, MC tot   9.48, MC disc   7.69, V0  20.29
# Episode 129, epsilon   0.01, batch size 1672, ep return  8.0, MC tot   9.34, MC disc   7.60, V0  20.10
# Episode 130, epsilon   0.01, batch size 1683, ep return 11.0, MC tot   9.26, MC disc   7.55, V0  19.77
# Episode 131, epsilon   0.01, batch size 1691, ep return  8.0, MC tot   9.56, MC disc   7.74, V0  19.89
# Episode 132, epsilon   0.01, batch size 1699, ep return  8.0, MC tot   9.42, MC disc   7.65, V0  19.58
# Episode 133, epsilon   0.01, batch size 1707, ep return  8.0, MC tot   9.42, MC disc   7.66, V0  21.11
# Episode 134, epsilon   0.01, batch size 1717, ep return 10.0, MC tot   9.22, MC disc   7.53, V0  20.36
# Episode 135, epsilon   0.01, batch size 1727, ep return 10.0, MC tot   9.26, MC disc   7.55, V0  20.75
# Episode 136, epsilon   0.01, batch size 1738, ep return 11.0, MC tot   9.34, MC disc   7.60, V0  21.04
# Episode 137, epsilon   0.01, batch size 1748, ep return 10.0, MC tot   9.22, MC disc   7.53, V0  20.77
# Episode 138, epsilon   0.01, batch size 1757, ep return  9.0, MC tot   9.42, MC disc   7.65, V0  20.78
# Episode 139, epsilon   0.01, batch size 1766, ep return  9.0, MC tot   9.44, MC disc   7.67, V0  21.27
# Episode 140, epsilon   0.01, batch size 1776, ep return 10.0, MC tot   9.42, MC disc   7.65, V0  21.12
# Episode 141, epsilon   0.01, batch size 1785, ep return  9.0, MC tot   9.50, MC disc   7.71, V0  21.11
# Episode 142, epsilon   0.01, batch size 1795, ep return 10.0, MC tot   9.48, MC disc   7.69, V0  22.04
# Episode 143, epsilon   0.01, batch size 1803, ep return  8.0, MC tot   9.32, MC disc   7.59, V0  21.55
# Episode 144, epsilon   0.01, batch size 1812, ep return  9.0, MC tot   9.44, MC disc   7.67, V0  22.59
# Episode 145, epsilon   0.01, batch size 1821, ep return  9.0, MC tot   9.32, MC disc   7.59, V0  22.04
# Episode 146, epsilon   0.01, batch size 1831, ep return 10.0, MC tot   9.30, MC disc   7.58, V0  21.33
# Episode 147, epsilon   0.01, batch size 1841, ep return 10.0, MC tot   9.50, MC disc   7.71, V0  21.55
# Episode 148, epsilon   0.01, batch size 1850, ep return  9.0, MC tot   9.34, MC disc   7.60, V0  21.76
# Episode 149, epsilon   0.01, batch size 1858, ep return  8.0, MC tot   9.50, MC disc   7.71, V0  23.29
# Episode 150, epsilon   0.01, batch size 1866, ep return  8.0, MC tot   9.24, MC disc   7.54, V0  22.29
# Episode 151, epsilon   0.01, batch size 1874, ep return  8.0, MC tot   9.30, MC disc   7.58, V0  23.11
# Episode 152, epsilon   0.01, batch size 1883, ep return  9.0, MC tot   9.32, MC disc   7.59, V0  22.99
# Episode 153, epsilon   0.01, batch size 1893, ep return 10.0, MC tot   9.46, MC disc   7.68, V0  22.65
# Episode 154, epsilon   0.01, batch size 1902, ep return  9.0, MC tot   9.42, MC disc   7.65, V0  21.92
# Episode 155, epsilon   0.01, batch size 1912, ep return 10.0, MC tot   9.46, MC disc   7.68, V0  23.81
# Episode 156, epsilon   0.01, batch size 1922, ep return 10.0, MC tot   9.62, MC disc   7.78, V0  23.12
# Episode 157, epsilon   0.01, batch size 1931, ep return  9.0, MC tot   9.36, MC disc   7.62, V0  23.52
# Episode 158, epsilon   0.01, batch size 1941, ep return 10.0, MC tot   9.22, MC disc   7.53, V0  23.60
# Episode 159, epsilon   0.01, batch size 1951, ep return 10.0, MC tot   9.42, MC disc   7.66, V0  23.71
# Episode 160, epsilon   0.01, batch size 1959, ep return  8.0, MC tot   9.42, MC disc   7.66, V0  24.89
# Episode 161, epsilon   0.01, batch size 1968, ep return  9.0, MC tot   9.20, MC disc   7.51, V0  24.23
# Episode 162, epsilon   0.01, batch size 1977, ep return  9.0, MC tot   9.40, MC disc   7.64, V0  24.64
# Episode 163, epsilon   0.01, batch size 1986, ep return  9.0, MC tot   9.38, MC disc   7.63, V0  23.27
# Episode 164, epsilon   0.01, batch size 1996, ep return 10.0, MC tot   9.36, MC disc   7.62, V0  24.41
# Episode 165, epsilon   0.01, batch size 2005, ep return  9.0, MC tot   9.50, MC disc   7.70, V0  24.09
# Episode 166, epsilon   0.01, batch size 2014, ep return  9.0, MC tot   9.44, MC disc   7.67, V0  23.78
# Episode 167, epsilon   0.01, batch size 2024, ep return 10.0, MC tot   9.50, MC disc   7.70, V0  25.43
# Episode 168, epsilon   0.01, batch size 2034, ep return 10.0, MC tot   9.24, MC disc   7.54, V0  23.95
# Episode 169, epsilon   0.01, batch size 2045, ep return 11.0, MC tot   9.32, MC disc   7.59, V0  24.82
# Episode 170, epsilon   0.01, batch size 2055, ep return 10.0, MC tot   9.28, MC disc   7.57, V0  24.63
# Episode 171, epsilon   0.01, batch size 2065, ep return 10.0, MC tot   9.26, MC disc   7.56, V0  25.11
# Episode 172, epsilon   0.01, batch size 2075, ep return 10.0, MC tot   9.38, MC disc   7.63, V0  25.72
# Episode 173, epsilon   0.01, batch size 2085, ep return 10.0, MC tot   9.42, MC disc   7.65, V0  25.24
# Episode 174, epsilon   0.01, batch size 2094, ep return  9.0, MC tot   9.30, MC disc   7.58, V0  25.40
# Episode 175, epsilon   0.01, batch size 2103, ep return  9.0, MC tot   9.42, MC disc   7.65, V0  24.55
# Episode 176, epsilon   0.01, batch size 2112, ep return  9.0, MC tot   9.34, MC disc   7.61, V0  26.76
# Episode 177, epsilon   0.01, batch size 2121, ep return  9.0, MC tot   9.62, MC disc   7.78, V0  25.26
# Episode 178, epsilon   0.01, batch size 2131, ep return 10.0, MC tot   9.38, MC disc   7.63, V0  25.02
# Episode 179, epsilon   0.01, batch size 2139, ep return  8.0, MC tot   9.38, MC disc   7.63, V0  25.96
# Episode 180, epsilon   0.01, batch size 2147, ep return  8.0, MC tot   9.28, MC disc   7.57, V0  25.19
# Episode 181, epsilon   0.01, batch size 2157, ep return 10.0, MC tot   9.34, MC disc   7.60, V0  26.02
# Episode 182, epsilon   0.01, batch size 2165, ep return  8.0, MC tot   9.14, MC disc   7.47, V0  26.33
# Episode 183, epsilon   0.01, batch size 2175, ep return 10.0, MC tot   9.50, MC disc   7.71, V0  25.49
# Episode 184, epsilon   0.01, batch size 2185, ep return 10.0, MC tot   9.28, MC disc   7.57, V0  26.72
# Episode 185, epsilon   0.01, batch size 2195, ep return 10.0, MC tot   9.38, MC disc   7.63, V0  26.35
# Episode 186, epsilon   0.01, batch size 2205, ep return 10.0, MC tot   9.28, MC disc   7.57, V0  25.81
# Episode 187, epsilon   0.01, batch size 2214, ep return  9.0, MC tot   9.26, MC disc   7.55, V0  27.14
# Episode 188, epsilon   0.01, batch size 2223, ep return  9.0, MC tot   9.20, MC disc   7.52, V0  26.82
# Episode 189, epsilon   0.01, batch size 2232, ep return  9.0, MC tot   9.34, MC disc   7.60, V0  26.37
# Episode 190, epsilon   0.01, batch size 2241, ep return  9.0, MC tot   9.12, MC disc   7.46, V0  26.89
# Episode 191, epsilon   0.01, batch size 2250, ep return  9.0, MC tot   9.16, MC disc   7.49, V0  26.30
# Episode 192, epsilon   0.01, batch size 2258, ep return  8.0, MC tot   9.22, MC disc   7.53, V0  26.63
# Episode 193, epsilon   0.01, batch size 2266, ep return  8.0, MC tot   9.32, MC disc   7.59, V0  28.02
# Episode 194, epsilon   0.01, batch size 2275, ep return  9.0, MC tot   9.32, MC disc   7.59, V0  27.70
# Episode 195, epsilon   0.01, batch size 2285, ep return 10.0, MC tot   9.20, MC disc   7.51, V0  26.52
# Episode 196, epsilon   0.01, batch size 2295, ep return 10.0, MC tot   9.40, MC disc   7.64, V0  27.05
# Episode 197, epsilon   0.01, batch size 2305, ep return 10.0, MC tot   9.36, MC disc   7.62, V0  27.26
# Episode 198, epsilon   0.01, batch size 2315, ep return 10.0, MC tot   9.40, MC disc   7.64, V0  26.73
# Episode 199, epsilon   0.01, batch size 2324, ep return  9.0, MC tot   9.44, MC disc   7.67, V0  28.16
# Episode 200, epsilon   0.01, batch size 2333, ep return  9.0, MC tot   9.46, MC disc   7.68, V0  28.06

# %% [markdown]
# ## Discussion
#
# Have you noted that Q overestimates the true value of the optimal policy? More on this in [this paper](https://papers.nips.cc/paper/3964-double-q-learning) if you are interested.
# Have you noted that the greedy policy is optimal much sooner than the $Q$ function?
# Have you remarked that the greedy policy performs well much sooner than the agent's policy (which is $\epsilon$-greedy)?
# Can you anticipate the importance of well tuned exploration, for instance if the state space is much larger, or if parts of it are very hard to reach?
# Can you anticipate the effect of taking a larger $\gamma$?

# %% [markdown]
# # Homework
#
# Double Q-learning
# n-step returns
# PER (maybe LaBER)
# distributional DQN (C51)
